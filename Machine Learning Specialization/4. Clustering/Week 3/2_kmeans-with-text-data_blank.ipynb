# %% [markdown]
# # k-means with text data

# %% [markdown]
# In this assignment you will
# * Cluster Wikipedia documents using k-means
# * Explore the role of random initialization on the quality of the clustering
# * Explore how results differ after changing the number of clusters
# * Evaluate clustering, both quantitatively and qualitatively
#
# When properly executed, clustering uncovers valuable insights from a set of unlabeled documents.

# %% [markdown]
# **Note to Amazon EC2 users**: To conserve memory, make sure to stop all the other notebooks before running this notebook.

# %% [markdown]
# ## Import necessary packages

# %% [markdown]
# The following code block will check if you have the correct version of GraphLab Create. Any version later than 1.8.5 will do. To upgrade, read [this page](https://turi.com/download/upgrade-graphlab-create.html).

# %%
import graphlab
import matplotlib.pyplot as plt
import numpy as np
import sys
import os
from scipy.sparse import csr_matrix

# %matplotlib inline

'''Check GraphLab Create version'''
from distutils.version import StrictVersion
assert (StrictVersion(graphlab.version) >= StrictVersion('1.8.5')), 'GraphLab Create must be version 1.8.5 or later.'
# Out:
# This non-commercial license of GraphLab Create for academic use is assigned to gniemiec@poczta.onet.pl and will expire on April 13, 2018.
# [INFO] graphlab.cython.cy_server: GraphLab Create v2.1 started. Logging: /tmp/graphlab_server_1519073969.log

# %% [markdown]
# ## Load data, extract features

# %% [markdown]
# To work with text data, we must first convert the documents into numerical features. As in the first assignment, let's extract TF-IDF features for each article.

# %%
wiki = graphlab.SFrame('people_wiki.gl/')

# %%
wiki['tf_idf'] = graphlab.text_analytics.tf_idf(wiki['text'])

# %% [markdown]
# For the remainder of the assignment, we will use sparse matrices. Sparse matrices are matrices that have a small number of nonzero entries. A good data structure for sparse matrices would only store the nonzero entries to save space and speed up computation. SciPy provides a highly-optimized library for sparse matrices. Many matrix operations available for NumPy arrays are also available for SciPy sparse matrices.
#
# We first convert the TF-IDF column (in dictionary format) into the SciPy sparse matrix format. We included plenty of comments for the curious; if you'd like, you may skip the next block and treat the function as a black box.

# %%
def sframe_to_scipy(x, column_name):
    '''
    Convert a dictionary column of an SFrame into a sparse matrix format where
    each (row_id, column_id, value) triple corresponds to the value of
    x[row_id][column_id], where column_id is a key in the dictionary.
       
    Example
    >>> sparse_matrix, map_key_to_index = sframe_to_scipy(sframe, column_name)
    '''
    assert x[column_name].dtype() == dict, \
        'The chosen column must be dict type, representing sparse data.'
        
    # Create triples of (row_id, feature_id, count).
    # 1. Add a row number.
    x = x.add_row_number()
    # 2. Stack will transform x to have a row for each unique (row, key) pair.
    x = x.stack(column_name, ['feature', 'value'])

    # Map words into integers using a OneHotEncoder feature transformation.
    f = graphlab.feature_engineering.OneHotEncoder(features=['feature'])
    # 1. Fit the transformer using the above data.
    f.fit(x)
    # 2. The transform takes 'feature' column and adds a new column 'feature_encoding'.
    x = f.transform(x)
    # 3. Get the feature mapping.
    mapping = f['feature_encoding']
    # 4. Get the feature id to use for each key.
    x['feature_id'] = x['encoded_features'].dict_keys().apply(lambda x: x[0])

    # Create numpy arrays that contain the data for the sparse matrix.
    i = np.array(x['id'])
    j = np.array(x['feature_id'])
    v = np.array(x['value'])
    width = x['id'].max() + 1
    height = x['feature_id'].max() + 1

    # Create a sparse matrix.
    mat = csr_matrix((v, (i, j)), shape=(width, height))

    return mat, mapping

# %%
# The conversion will take about a minute or two.
tf_idf, map_index_to_word = sframe_to_scipy(wiki, 'tf_idf')

# %%
for i in range(0,1000,1):
    for j in range(0,1000,1):
        if tf_idf [i,j] <> 0:
            print i
            print j
            #print wiki [i]
            print map_index_to_word[j]
            print tf_idf [i,j]
# Out:
# 6
# 286
# {'category': 'pellatfinet', 'index': 286, 'feature': 'feature'}
# 10.9864953892
# 18
# 949
# {'category': 'unionnaxos', 'index': 949, 'feature': 'feature'}
# 10.9864953892
# 36
# 844
# {'category': 'suissebrm', 'index': 844, 'feature': 'feature'}
# 10.9864953892
# 51
# 45
# {'category': 'mcin', 'index': 45, 'feature': 'feature'}
# 10.9864953892
# 122
# 520
# {'category': 'hailpin', 'index': 520, 'feature': 'feature'}
# 10.9864953892
# 154
# 204
# {'category': 'topshops', 'index': 204, 'feature': 'feature'}
# 10.9864953892
# 404
# 234
# {'category': 'comendadora', 'index': 234, 'feature': 'feature'}
# 10.9864953892
# 469
# 651
# {'category': 'chole', 'index': 651, 'feature': 'feature'}
# 10.9864953892
# 560
# 47
# {'category': 'sumiswald', 'index': 47, 'feature': 'feature'}
# 10.9864953892
# 597
# 148
# {'category': 'rheinfelden', 'index': 148, 'feature': 'feature'}
# 10.9864953892
# 616
# 232
# {'category': 'tucuman', 'index': 232, 'feature': 'feature'}
# 10.9864953892
# 754
# 263
# {'category': 'turangalilasymphony', 'index': 263, 'feature': 'feature'}
# 10.9864953892
# 817
# 900
# {'category': 'advocacies', 'index': 900, 'feature': 'feature'}
# 10.9864953892
# 933
# 503
# {'category': 'computeraidedtranscription', 'index': 503, 'feature': 'feature'}
# 10.9864953892

# %%
#map_index_to_word
# Out:
# 0.0

# %% [markdown]
# The above matrix contains a TF-IDF score for each of the 59071 pages in the data set and each of the 547979 unique words.

# %% [markdown]
# ## Normalize all vectors

# %% [markdown]
# As discussed in the previous assignment, Euclidean distance can be a poor metric of similarity between documents, as it unfairly penalizes long articles. For a reasonable assessment of similarity, we should disregard the length information and use length-agnostic metrics, such as cosine distance.
#
# The k-means algorithm does not directly work with cosine distance, so we take an alternative route to remove length information: we normalize all vectors to be unit length. It turns out that Euclidean distance closely mimics cosine distance when all vectors are unit length. In particular, the squared Euclidean distance between any two vectors of length one is directly proportional to their cosine distance.
#
# We can prove this as follows. Let $\mathbf{x}$ and $\mathbf{y}$ be normalized vectors, i.e. unit vectors, so that $\|\mathbf{x}\|=\|\mathbf{y}\|=1$. Write the squared Euclidean distance as the dot product of $(\mathbf{x} - \mathbf{y})$ to itself:
# \begin{align*}
# \|\mathbf{x} - \mathbf{y}\|^2 &= (\mathbf{x} - \mathbf{y})^T(\mathbf{x} - \mathbf{y})\\
#                               &= (\mathbf{x}^T \mathbf{x}) - 2(\mathbf{x}^T \mathbf{y}) + (\mathbf{y}^T \mathbf{y})\\
#                               &= \|\mathbf{x}\|^2 - 2(\mathbf{x}^T \mathbf{y}) + \|\mathbf{y}\|^2\\
#                               &= 2 - 2(\mathbf{x}^T \mathbf{y})\\
#                               &= 2(1 - (\mathbf{x}^T \mathbf{y}))\\
#                               &= 2\left(1 - \frac{\mathbf{x}^T \mathbf{y}}{\|\mathbf{x}\|\|\mathbf{y}\|}\right)\\
#                               &= 2\left[\text{cosine distance}\right]
# \end{align*}
#
# This tells us that two **unit vectors** that are close in Euclidean distance are also close in cosine distance. Thus, the k-means algorithm (which naturally uses Euclidean distances) on normalized vectors will produce the same results as clustering using cosine distance as a distance metric.
#
# We import the [`normalize()` function](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.normalize.html) from scikit-learn to normalize all vectors to unit length.

# %%
from sklearn.preprocessing import normalize
tf_idf = normalize(tf_idf)

# %% [markdown]
# ## Implement k-means

# %% [markdown]
# Let us implement the k-means algorithm. First, we choose an initial set of centroids. A common practice is to choose randomly from the data points.
#
# **Note:** We specify a seed here, so that everyone gets the same answer. In practice, we highly recommend to use different seeds every time (for instance, by using the current timestamp).

# %%
def get_initial_centroids(data, k, seed=None):
    '''Randomly choose k data points as initial centroids'''
    if seed is not None: # useful for obtaining consistent results
        np.random.seed(seed)
    n = data.shape[0] # number of data points
        
    # Pick K indices from range [0, N).
    rand_indices = np.random.randint(0, n, k)
    
    # Keep centroids as dense format, as many entries will be nonzero due to averaging.
    # As long as at least one document in a cluster contains a word,
    # it will carry a nonzero weight in the TF-IDF vector of the centroid.
    centroids = data[rand_indices,:].toarray()
    
    return centroids

# %% [markdown]
# After initialization, the k-means algorithm iterates between the following two steps:
# 1. Assign each data point to the closest centroid.
# $$
# z_i \gets \mathrm{argmin}_j \|\mu_j - \mathbf{x}_i\|^2
# $$
# 2. Revise centroids as the mean of the assigned data points.
# $$
# \mu_j \gets \frac{1}{n_j}\sum_{i:z_i=j} \mathbf{x}_i
# $$

# %% [markdown]
# In pseudocode, we iteratively do the following:
# ```
# cluster_assignment = assign_clusters(data, centroids)
# centroids = revise_centroids(data, k, cluster_assignment)
# ```

# %% [markdown]
# ### Assigning clusters

# %% [markdown]
# How do we implement Step 1 of the main k-means loop above? First import `pairwise_distances` function from scikit-learn, which calculates Euclidean distances between rows of given arrays. See [this documentation](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.pairwise.pairwise_distances.html) for more information.
#
# For the sake of demonstration, let's look at documents 100 through 102 as query documents and compute the distances between each of these documents and every other document in the corpus. In the k-means algorithm, we will have to compute pairwise distances between the set of centroids and the set of documents.

# %%
from sklearn.metrics import pairwise_distances

# Get the TF-IDF vectors for documents 100 through 102.
queries = tf_idf[100:102,:]

# Compute pairwise distances from every data point to each query vector.
dist = pairwise_distances(tf_idf, queries, metric='euclidean')

print dist
# Out:
# [[ 1.41000789  1.36894636]
#  [ 1.40935215  1.41023886]
#  [ 1.39855967  1.40890299]
#  ...,
#  [ 1.41108296  1.39123646]
#  [ 1.41022804  1.31468652]
#  [ 1.39899784  1.41072448]]

# %% [markdown]
# More formally, `dist[i,j]` is assigned the distance between the `i`th row of `X` (i.e., `X[i,:]`) and the `j`th row of `Y` (i.e., `Y[j,:]`).

# %% [markdown]
# **Checkpoint:** For a moment, suppose that we initialize three centroids with the first 3 rows of `tf_idf`. Write code to compute distances from each of the centroids to all data points in `tf_idf`. Then find the distance between row 430 of `tf_idf` and the second centroid and save it to `dist`.

# %%
# Students should write code here
queries = tf_idf[0:3,:]


# Compute pairwise distances from every data point to each query vector.
distances = pairwise_distances(tf_idf, queries, metric='euclidean')

dist =  pairwise_distances(tf_idf[430,], queries[1], metric='euclidean')

# %%
distances
# Out:
# array([[ 0.        ,  1.40775177,  1.38784582],
#        [ 1.40775177,  0.        ,  1.39867641],
#        [ 1.38784582,  1.39867641,  0.        ],
#        ...,
#        [ 1.37070999,  1.40978937,  1.40616385],
#        [ 1.35214578,  1.41306211,  1.40869799],
#        [ 1.40799024,  1.41353429,  1.40903605]])

# %%
'''Test cell'''
if np.allclose(dist, pairwise_distances(tf_idf[430,:], tf_idf[1,:])):
    print('Pass')
else:
    print('Check your code again')
# Out:
# Pass

# %% [markdown]
# **Checkpoint:** Next, given the pairwise distances, we take the minimum of the distances for each data point. Fittingly, NumPy provides an `argmin` function. See [this documentation](http://docs.scipy.org/doc/numpy-1.10.1/reference/generated/numpy.argmin.html) for details.
#
# Read the documentation and write code to produce a 1D array whose i-th entry indicates the centroid that is the closest to the i-th data point. Use the list of distances from the previous checkpoint and save them as `distances`. The value 0 indicates closeness to the first centroid, 1 indicates closeness to the second centroid, and so forth. Save this array as `closest_cluster`.
#
# **Hint:** the resulting array should be as long as the number of data points.

# %%
# Students should write code here
#a = np.arange(9).reshape(2,3)
#a
#array([[0, 1, 2],
#       [3, 1, 5]])
#np.argmin(a)
#0
#np.argmin(a, axis=0)
#array([0, 0, 0])
#np.argmin(a, axis=1)
#array([0, 0])

# %%
closest_cluster = np.argmin(distances, axis=1)

# %%
closest_cluster
# Out:
# array([0, 1, 2, ..., 0, 0, 0])

# %%
'''Test cell'''
reference = [list(row).index(min(row)) for row in distances]
if np.allclose(closest_cluster, reference):
    print('Pass')
else:
    print('Check your code again')
# Out:
# Pass

# %% [markdown]
# **Checkpoint:** Let's put these steps together.  First, initialize three centroids with the first 3 rows of `tf_idf`. Then, compute distances from each of the centroids to all data points in `tf_idf`. Finally, use these distance calculations to compute cluster assignments and assign them to `cluster_assignment`.

# %%
# Students should write code here
centroids = tf_idf[0:3,:]
distances = pairwise_distances(tf_idf, centroids, metric='euclidean')
cluster_assignment = np.argmin(distances, axis=1)

# %%
if len(cluster_assignment)==59071 and \
   np.array_equal(np.bincount(cluster_assignment), np.array([23061, 10086, 25924])):
    print('Pass') # count number of data points for each cluster
else:
    print('Check your code again.')
# Out:
# Pass

# %% [markdown]
# Now we are ready to fill in the blanks in this function:

# %%
def assign_clusters(data, centroids):
    
    # Compute distances between each data point and the set of centroids:
    # Fill in the blank (RHS only)
    distances_from_centroids = pairwise_distances(data, centroids, metric='euclidean')
    
    # Compute cluster assignments for each data point:
    # Fill in the blank (RHS only)
    cluster_assignment = np.argmin(distances_from_centroids, axis=1)
    
    return cluster_assignment

# %% [markdown]
# **Checkpoint**. For the last time, let us check if Step 1 was implemented correctly. With rows 0, 2, 4, and 6 of `tf_idf` as an initial set of centroids, we assign cluster labels to rows 0, 10, 20, ..., and 90 of `tf_idf`. The resulting cluster labels should be `[0, 1, 1, 0, 0, 2, 0, 2, 2, 1]`.

# %%
if np.allclose(assign_clusters(tf_idf[0:100:10], tf_idf[0:8:2]), np.array([0, 1, 1, 0, 0, 2, 0, 2, 2, 1])):
    print('Pass')
else:
    print('Check your code again.')
# Out:
# Pass

# %% [markdown]
# ### Revising clusters

# %% [markdown]
# Let's turn to Step 2, where we compute the new centroids given the cluster assignments.

# %% [markdown]
# SciPy and NumPy arrays allow for filtering via Boolean masks. For instance, we filter all data points that are assigned to cluster 0 by writing
# ```
# data[cluster_assignment==0,:]
# ```

# %% [markdown]
# To develop intuition about filtering, let's look at a toy example consisting of 3 data points and 2 clusters.

# %%
data = np.array([[1., 2., 0.],
                 [0., 0., 0.],
                 [2., 2., 0.]])
centroids = np.array([[0.5, 0.5, 0.],
                      [0., -0.5, 0.]])

# %% [markdown]
# Let's assign these data points to the closest centroid.

# %%
cluster_assignment = assign_clusters(data, centroids)
print cluster_assignment
# Out:
# [0 1 0]

# %% [markdown]
# The expression `cluster_assignment==1` gives a list of Booleans that says whether each data point is assigned to cluster 1 or not:

# %%
cluster_assignment==1
# Out:
# array([False,  True, False], dtype=bool)

# %% [markdown]
# Likewise for cluster 0:

# %%
cluster_assignment==0
# Out:
# array([ True, False,  True], dtype=bool)

# %% [markdown]
# In lieu of indices, we can put in the list of Booleans to pick and choose rows. Only the rows that correspond to a `True` entry will be retained.
#
# First, let's look at the data points (i.e., their values) assigned to cluster 1:

# %%
data[cluster_assignment==1]
# Out:
# array([[ 0.,  0.,  0.]])

# %% [markdown]
# This makes sense since [0 0 0] is closer to [0 -0.5 0] than to [0.5 0.5 0].
#
# Now let's look at the data points assigned to cluster 0:

# %%
data[cluster_assignment==0]
# Out:
# array([[ 1.,  2.,  0.],
#        [ 2.,  2.,  0.]])

# %% [markdown]
# Again, this makes sense since these values are each closer to [0.5 0.5 0] than to [0 -0.5 0].
#
# Given all the data points in a cluster, it only remains to compute the mean. Use [np.mean()](http://docs.scipy.org/doc/numpy-1.10.0/reference/generated/numpy.mean.html). By default, the function averages all elements in a 2D array. To compute row-wise or column-wise means, add the `axis` argument. See the linked documentation for details.
#
# Use this function to average the data points in cluster 0:

# %%
data[cluster_assignment==0].mean(axis=0)
# Out:
# array([ 1.5,  2. ,  0. ])

# %% [markdown]
# We are now ready to complete this function:

# %%
def revise_centroids(data, k, cluster_assignment):
    new_centroids = []
    for i in xrange(k):
        # Select all data points that belong to cluster i. Fill in the blank (RHS only)
        member_data_points = data[cluster_assignment==i]
        # Compute the mean of the data points. Fill in the blank (RHS only)
        centroid = member_data_points.mean(axis=0)
        
        # Convert numpy.matrix type to numpy.ndarray type
        centroid = centroid.A1
        new_centroids.append(centroid)
    new_centroids = np.array(new_centroids)
    
    return new_centroids

# %% [markdown]
# **Checkpoint**. Let's check our Step 2 implementation. Letting rows 0, 10, ..., 90 of `tf_idf` as the data points and the cluster labels `[0, 1, 1, 0, 0, 2, 0, 2, 2, 1]`, we compute the next set of centroids. Each centroid is given by the average of all member data points in corresponding cluster.

# %%
result = revise_centroids(tf_idf[0:100:10], 3, np.array([0, 1, 1, 0, 0, 2, 0, 2, 2, 1]))
if np.allclose(result[0], np.mean(tf_idf[[0,30,40,60]].toarray(), axis=0)) and \
   np.allclose(result[1], np.mean(tf_idf[[10,20,90]].toarray(), axis=0))   and \
   np.allclose(result[2], np.mean(tf_idf[[50,70,80]].toarray(), axis=0)):
    print('Pass')
else:
    print('Check your code')
# Out:
# Pass

# %% [markdown]
# ### Assessing convergence

# %% [markdown]
# How can we tell if the k-means algorithm is converging? We can look at the cluster assignments and see if they stabilize over time. In fact, we'll be running the algorithm until the cluster assignments stop changing at all. To be extra safe, and to assess the clustering performance, we'll be looking at an additional criteria: the sum of all squared distances between data points and centroids. This is defined as
# $$
# J(\mathcal{Z},\mu) = \sum_{j=1}^k \sum_{i:z_i = j} \|\mathbf{x}_i - \mu_j\|^2.
# $$
# The smaller the distances, the more homogeneous the clusters are. In other words, we'd like to have "tight" clusters.

# %%
def compute_heterogeneity(data, k, centroids, cluster_assignment):
    
    heterogeneity = 0.0
    for i in xrange(k):
        
        # Select all data points that belong to cluster i. Fill in the blank (RHS only)
        member_data_points = data[cluster_assignment==i, :]
        
        if member_data_points.shape[0] > 0: # check if i-th cluster is non-empty
            # Compute distances from centroid to data points (RHS only)
            distances = pairwise_distances(member_data_points, [centroids[i]], metric='euclidean')
            squared_distances = distances**2
            heterogeneity += np.sum(squared_distances)
        
    return heterogeneity

# %% [markdown]
# Let's compute the cluster heterogeneity for the 2-cluster example we've been considering based on our current cluster assignments and centroids.

# %%
compute_heterogeneity(data, 2, centroids, cluster_assignment)
# Out:
# 7.25

# %% [markdown]
# ### Combining into a single function

# %% [markdown]
# Once the two k-means steps have been implemented, as well as our heterogeneity metric we wish to monitor, it is only a matter of putting these functions together to write a k-means algorithm that
#
# * Repeatedly performs Steps 1 and 2
# * Tracks convergence metrics
# * Stops if either no assignment changed or we reach a certain number of iterations.

# %%
# Fill in the blanks
def kmeans(data, k, initial_centroids, maxiter, record_heterogeneity=None, verbose=False):
    '''This function runs k-means on given data and initial set of centroids.
       maxiter: maximum number of iterations to run.
       record_heterogeneity: (optional) a list, to store the history of heterogeneity as function of iterations
                             if None, do not store the history.
       verbose: if True, print how many data points changed their cluster labels in each iteration'''
    centroids = initial_centroids[:]
    prev_cluster_assignment = None
    
    for itr in xrange(maxiter):        
        if verbose:
            print(itr)
        
        # 1. Make cluster assignments using nearest centroids
        # YOUR CODE HERE
        cluster_assignment = assign_clusters(data, centroids)
            
        # 2. Compute a new centroid for each of the k clusters, averaging all data points assigned to that cluster.
        # YOUR CODE HERE
        centroids = revise_centroids(data, k, cluster_assignment)
            
        # Check for convergence: if none of the assignments changed, stop
        if prev_cluster_assignment is not None and \
          (prev_cluster_assignment==cluster_assignment).all():
            break
        
        # Print number of new assignments 
        if prev_cluster_assignment is not None:
            num_changed = np.sum(prev_cluster_assignment!=cluster_assignment)
            if verbose:
                print('    {0:5d} elements changed their cluster assignment.'.format(num_changed))   
        
        # Record heterogeneity convergence metric
        if record_heterogeneity is not None:
            # YOUR CODE HERE
            score = compute_heterogeneity(data, k, centroids, cluster_assignment)
            record_heterogeneity.append(score)
        
        prev_cluster_assignment = cluster_assignment[:]
        
    return centroids, cluster_assignment

# %% [markdown]
# ## Plotting convergence metric

# %% [markdown]
# We can use the above function to plot the convergence metric across iterations.

# %%
def plot_heterogeneity(heterogeneity, k):
    plt.figure(figsize=(7,4))
    plt.plot(heterogeneity, linewidth=4)
    plt.xlabel('# Iterations')
    plt.ylabel('Heterogeneity')
    plt.title('Heterogeneity of clustering over time, K={0:d}'.format(k))
    plt.rcParams.update({'font.size': 16})
    plt.tight_layout()

# %% [markdown]
# Let's consider running k-means with K=3 clusters for a maximum of 400 iterations, recording cluster heterogeneity at every step.  Then, let's plot the heterogeneity over iterations using the plotting function above.

# %%
k = 3
heterogeneity = []
initial_centroids = get_initial_centroids(tf_idf, k, seed=0)
centroids, cluster_assignment = kmeans(tf_idf, k, initial_centroids, maxiter=400,
                                       record_heterogeneity=heterogeneity, verbose=True)
plot_heterogeneity(heterogeneity, k)
# Out:
# 0
# 1
#     19157 elements changed their cluster assignment.
# 2
#      7739 elements changed their cluster assignment.
# 3
#      5119 elements changed their cluster assignment.
# 4
#      3370 elements changed their cluster assignment.
# 5
#      2811 elements changed their cluster assignment.
# 6
#      3233 elements changed their cluster assignment.
# 7
#      3815 elements changed their cluster assignment.
# 8
#      3172 elements changed their cluster assignment.
# 9
#      1149 elements changed their cluster assignment.
# 10
#       498 elements changed their cluster assignment.
# 11
#       265 elements changed their cluster assignment.
# 12
#       149 elements changed their cluster assignment.
# 13
#       100 elements changed their cluster assignment.
# 14
#        76 elements changed their cluster assignment.
# 15
#        67 elements changed their cluster assignment.
# 16
#        51 elements changed their cluster assignment.
# 17
#        47 elements changed their cluster assignment.
# 18
#        40 elements changed their cluster assignment.
# 19
#        34 elements changed their cluster assignment.
# 20
#        35 elements changed their cluster assignment.
# 21
#        39 elements changed their cluster assignment.
# 22
#        24 elements changed their cluster assignment.
# 23
#        16 elements changed their cluster assignment.
# 24
#        12 elements changed their cluster assignment.
# 25
#        14 elements changed their cluster assignment.
# 26
#        17 elements changed their cluster assignment.
# 27
#        15 elements changed their cluster assignment.
# 28
#        14 elements changed their cluster assignment.
# 29
#        16 elements changed their cluster assignment.
# 30
#        21 elements changed their cluster assignment.
# 31
#        22 elements changed their cluster assignment.
# 32
#        33 elements changed their cluster assignment.
# 33
#        35 elements changed their cluster assignment.
# 34
#        39 elements changed their cluster assignment.
# 35
#        36 elements changed their cluster assignment.
# 36
#        36 elements changed their cluster assignment.
# 37
#        25 elements changed their cluster assignment.
# 38
#        27 elements changed their cluster assignment.
# 39
#        25 elements changed their cluster assignment.
# 40
#        28 elements changed their cluster assignment.
# 41
#        35 elements changed their cluster assignment.
# 42
#        31 elements changed their cluster assignment.
# 43
#        25 elements changed their cluster assignment.
# 44
#        18 elements changed their cluster assignment.
# 45
#        15 elements changed their cluster assignment.
# 46
#        10 elements changed their cluster assignment.
# 47
#         8 elements changed their cluster assignment.
# 48
#         8 elements changed their cluster assignment.
# 49
#         8 elements changed their cluster assignment.
# 50
#         7 elements changed their cluster assignment.
# 51
#         8 elements changed their cluster assignment.
# 52
#         3 elements changed their cluster assignment.
# 53
#         3 elements changed their cluster assignment.
# 54
#         4 elements changed their cluster assignment.
# 55
#         2 elements changed their cluster assignment.
# 56
#         3 elements changed their cluster assignment.
# 57
#         3 elements changed their cluster assignment.
# 58
#         1 elements changed their cluster assignment.
# 59
#         1 elements changed their cluster assignment.
# 60

# %% [markdown]
# **Quiz Question**. (True/False) The clustering objective (heterogeneity) is non-increasing for this example.

# %% [markdown]
# **Quiz Question**. Let's step back from this particular example. If the clustering objective (heterogeneity) would ever increase when running k-means, that would indicate: (choose one)
#
# 1. k-means algorithm got stuck in a bad local minimum
# 2. There is a bug in the k-means code
# 3. All data points consist of exact duplicates
# 4. Nothing is wrong. The objective should generally go down sooner or later.

# %% [markdown]
# **Quiz Question**. Which of the cluster contains the greatest number of data points in the end? Hint: Use [`np.bincount()`](http://docs.scipy.org/doc/numpy-1.11.0/reference/generated/numpy.bincount.html) to count occurrences of each cluster label.
#  1. Cluster #0
#  2. Cluster #1
#  3. Cluster #2

# %%
centroids
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.13957629e-04,   9.38937922e-05,   1.98350206e-05],
#        [  0.00000000e+00,   9.46593597e-06,   0.00000000e+00, ...,
#           1.37670861e-04,   6.49631597e-05,   2.27433941e-05],
#        [  4.92624714e-06,   0.00000000e+00,   4.72954750e-06, ...,
#           1.09191883e-04,   8.63979609e-05,   2.07849580e-05]])

# %%
cluster_assignment
# Out:
# array([1, 2, 0, ..., 1, 1, 2])

# %%
np.bincount(cluster_assignment)
# Out:
# array([19595, 10427, 29049])

# %% [markdown]
# ## Beware of local maxima

# %% [markdown]
# One weakness of k-means is that it tends to get stuck in a local minimum. To see this, let us run k-means multiple times, with different initial centroids created using different random seeds.
#
# **Note:** Again, in practice, you should set different seeds for every run. We give you a list of seeds for this assignment so that everyone gets the same answer.
#
# This may take several minutes to run.

# %%
k = 10
heterogeneity = {}
import time
start = time.time()
for seed in [0, 20000, 40000, 60000, 80000, 100000, 120000]:
    initial_centroids = get_initial_centroids(tf_idf, k, seed)
    centroids, cluster_assignment = kmeans(tf_idf, k, initial_centroids, maxiter=400,
                                           record_heterogeneity=None, verbose=False)
    # To save time, compute heterogeneity only once in the end
    heterogeneity[seed] = compute_heterogeneity(tf_idf, k, centroids, cluster_assignment)
    
    max_cluster_size = max(np.bincount(cluster_assignment))
    min_cluster_size = min(np.bincount(cluster_assignment))
    
    print('seed={0:06d}, heterogeneity={1:.5f}, min_cluster_size={2:d}, max_cluster_size={3:d}'.
          format(seed, heterogeneity[seed],min_cluster_size,max_cluster_size))
    sys.stdout.flush()
end = time.time()
print(end-start)
# Out:
# seed=000000, heterogeneity=57457.52442, min_cluster_size=1492, max_cluster_size=18047
# seed=020000, heterogeneity=57533.20100, min_cluster_size=768, max_cluster_size=15779
# seed=040000, heterogeneity=57512.69257, min_cluster_size=186, max_cluster_size=18132
# seed=060000, heterogeneity=57466.97925, min_cluster_size=424, max_cluster_size=17900
# seed=080000, heterogeneity=57494.92990, min_cluster_size=809, max_cluster_size=17582
# seed=100000, heterogeneity=57484.42210, min_cluster_size=1337, max_cluster_size=16969
# seed=120000, heterogeneity=57554.62410, min_cluster_size=1608, max_cluster_size=16481
# 266.503700972

# %% [markdown]
# Notice the variation in heterogeneity for different initializations. This indicates that k-means sometimes gets stuck at a bad local minimum.

# %% [markdown]
# **Quiz Question**. Another way to capture the effect of changing initialization is to look at the distribution of cluster assignments. Add a line to the code above to compute the size (# of member data points) of clusters for each run of k-means. Look at the size of the largest cluster (most # of member data points) across multiple runs, with seeds 0, 20000, ..., 120000. How much does this measure vary across the runs? What is the minimum and maximum values this quantity takes?

# %% [markdown]
# One effective way to counter this tendency is to use **k-means++** to provide a smart initialization. This method tries to spread out the initial set of centroids so that they are not too close together. It is known to improve the quality of local optima and lower average runtime.

# %%
def smart_initialize(data, k, seed=None):
    '''Use k-means++ to initialize a good set of centroids'''
    if seed is not None: # useful for obtaining consistent results
        np.random.seed(seed)
    centroids = np.zeros((k, data.shape[1]))
    
    # Randomly choose the first centroid.
    # Since we have no prior knowledge, choose uniformly at random
    idx = np.random.randint(data.shape[0])
    centroids[0] = data[idx,:].toarray()
    # Compute distances from the first centroid chosen to all the other data points
    distances = pairwise_distances(data, centroids[0:1], metric='euclidean').flatten()
    
    for i in xrange(1, k):
        # Choose the next centroid randomly, so that the probability for each data point to be chosen
        # is directly proportional to its squared distance from the nearest centroid.
        # Roughtly speaking, a new centroid should be as far as from ohter centroids as possible.
        idx = np.random.choice(data.shape[0], 1, p=distances/sum(distances))
        centroids[i] = data[idx,:].toarray()
        # Now compute distances from the centroids to all data points
        distances = np.min(pairwise_distances(data, centroids[0:i+1], metric='euclidean'),axis=1)
    
    return centroids

# %% [markdown]
# Let's now rerun k-means with 10 clusters using the same set of seeds, but always using k-means++ to initialize the algorithm.
#
# This may take several minutes to run.

# %%
k = 10
heterogeneity_smart = {}
start = time.time()
for seed in [0, 20000, 40000, 60000, 80000, 100000, 120000]:
    initial_centroids = smart_initialize(tf_idf, k, seed)
    centroids, cluster_assignment = kmeans(tf_idf, k, initial_centroids, maxiter=400,
                                           record_heterogeneity=None, verbose=False)
    # To save time, compute heterogeneity only once in the end
    heterogeneity_smart[seed] = compute_heterogeneity(tf_idf, k, centroids, cluster_assignment)
    #print('seed={0:06d}, heterogeneity={1:.5f}'.format(seed, heterogeneity_smart[seed]))
    
    max_cluster_size = max(np.bincount(cluster_assignment))
    min_cluster_size = min(np.bincount(cluster_assignment))
    
    print('seed={0:06d}, heterogeneity={1:.5f}, min_cluster_size={2:d}, max_cluster_size={3:d}'.
          format(seed, heterogeneity_smart[seed],min_cluster_size,max_cluster_size))
    
    sys.stdout.flush()
end = time.time()
print(end-start)
# Out:
# seed=000000, heterogeneity=57441.33298, min_cluster_size=1346, max_cluster_size=17791
# seed=020000, heterogeneity=57457.50383, min_cluster_size=1535, max_cluster_size=18214
# seed=040000, heterogeneity=57469.82237, min_cluster_size=1738, max_cluster_size=20919
# seed=060000, heterogeneity=57503.05355, min_cluster_size=766, max_cluster_size=18574
# seed=080000, heterogeneity=57464.05684, min_cluster_size=1348, max_cluster_size=18723
# seed=100000, heterogeneity=57487.57010, min_cluster_size=1674, max_cluster_size=18088
# seed=120000, heterogeneity=57534.79120, min_cluster_size=760, max_cluster_size=15800
# 390.734215975

# %% [markdown]
# Let's compare the set of cluster heterogeneities we got from our 7 restarts of k-means using random initialization compared to the 7 restarts of k-means using k-means++ as a smart initialization.
#
# The following code produces a [box plot](http://matplotlib.org/api/pyplot_api.html) for each of these methods, indicating the spread of values produced by each method.

# %%
plt.figure(figsize=(8,5))
plt.boxplot([heterogeneity.values(), heterogeneity_smart.values()], vert=False)
plt.yticks([1, 2], ['k-means', 'k-means++'])
plt.rcParams.update({'font.size': 16})
plt.tight_layout()

# %% [markdown]
# A few things to notice from the box plot:
# * Random initialization results in a worse clustering than k-means++ on average.
# * The best result of k-means++ is better than the best result of random initialization.

# %% [markdown]
# **In general, you should run k-means at least a few times with different initializations and then return the run resulting in the lowest heterogeneity.** Let us write a function that runs k-means multiple times and picks the best run that minimizes heterogeneity. The function accepts an optional list of seed values to be used for the multiple runs; if no such list is provided, the current UTC time is used as seed values.

# %%
def kmeans_multiple_runs(data, k, maxiter, num_runs, seed_list=None, verbose=False):
    heterogeneity = {}
    
    min_heterogeneity_achieved = float('inf')
    best_seed = None
    final_centroids = None
    final_cluster_assignment = None
    
    for i in xrange(num_runs):
        
        # Use UTC time if no seeds are provided 
        if seed_list is not None: 
            seed = seed_list[i]
            np.random.seed(seed)
        else: 
            seed = int(time.time())
            np.random.seed(seed)
        
        # Use k-means++ initialization
        # YOUR CODE HERE
        initial_centroids = smart_initialize(data, k, seed)
        
        # Run k-means
        # YOUR CODE HERE
        centroids, cluster_assignment = kmeans(data, k, initial_centroids, maxiter=maxiter,
                                           record_heterogeneity=None, verbose=verbose)
        
        # To save time, compute heterogeneity only once in the end
        # YOUR CODE HERE
        heterogeneity[seed] = compute_heterogeneity(data, k, centroids, cluster_assignment)
        
        if verbose:
            print('seed={0:06d}, heterogeneity={1:.5f}'.format(seed, heterogeneity[seed]))
            sys.stdout.flush()
        
        # if current measurement of heterogeneity is lower than previously seen,
        # update the minimum record of heterogeneity.
        if heterogeneity[seed] < min_heterogeneity_achieved:
            min_heterogeneity_achieved = heterogeneity[seed]
            best_seed = seed
            final_centroids = centroids
            final_cluster_assignment = cluster_assignment
    
    # Return the centroids and cluster assignments that minimize heterogeneity.
    return final_centroids, final_cluster_assignment

# %% [markdown]
# ## How to choose K

# %% [markdown]
# Since we are measuring the tightness of the clusters, a higher value of K reduces the possible heterogeneity metric by definition.  For example, if we have N data points and set K=N clusters, then we could have 0 cluster heterogeneity by setting the N centroids equal to the values of the N data points. (Note: Not all runs for larger K will result in lower heterogeneity than a single run with smaller K due to local optima.)  Let's explore this general trend for ourselves by performing the following analysis.

# %% [markdown]
# Use the `kmeans_multiple_runs` function to run k-means with five different values of K.  For each K, use k-means++ and multiple runs to pick the best solution.  In what follows, we consider K=2,10,25,50,100 and 7 restarts for each setting.
#
# **IMPORTANT: The code block below will take about one hour to finish. We highly suggest that you use the arrays that we have computed for you.**
#
# Side note: In practice, a good implementation of k-means would utilize parallelism to run multiple runs of k-means at once. For an example, see [scikit-learn's KMeans](http://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html).

# %%
def plot_k_vs_heterogeneity(k_values, heterogeneity_values):
    plt.figure(figsize=(7,4))
    plt.plot(k_values, heterogeneity_values, linewidth=4)
    plt.xlabel('K')
    plt.ylabel('Heterogeneity')
    plt.title('K vs. Heterogeneity')
    plt.rcParams.update({'font.size': 16})
    plt.tight_layout()

start = time.time()
centroids = {}
cluster_assignment = {}
heterogeneity_values = []
k_list = [2, 10, 25, 50, 100]
seed_list = [0, 20000, 40000, 60000, 80000, 100000, 120000]

for k in k_list:
    heterogeneity = []
    centroids[k], cluster_assignment[k] = kmeans_multiple_runs(tf_idf, k, maxiter=400,
                                                               num_runs=len(seed_list),
                                                               seed_list=seed_list,
                                                               verbose=True)
    score = compute_heterogeneity(tf_idf, k, centroids[k], cluster_assignment[k])
    heterogeneity_values.append(score)

plot_k_vs_heterogeneity(k_list, heterogeneity_values)

end = time.time()
print(end-start)
# Out:
# 0
# 1
#     14956 elements changed their cluster assignment.
# 2
#      3938 elements changed their cluster assignment.
# 3
#      1240 elements changed their cluster assignment.
# 4
#       424 elements changed their cluster assignment.
# 5
#       238 elements changed their cluster assignment.
# 6
#       154 elements changed their cluster assignment.
# 7
#       116 elements changed their cluster assignment.
# 8
#        73 elements changed their cluster assignment.
# 9
#        50 elements changed their cluster assignment.
# 10
#        43 elements changed their cluster assignment.
# 11
#        37 elements changed their cluster assignment.
# 12
#        23 elements changed their cluster assignment.
# 13
#        13 elements changed their cluster assignment.
# 14
#        10 elements changed their cluster assignment.
# 15
#         5 elements changed their cluster assignment.
# 16
#         6 elements changed their cluster assignment.
# 17
#         4 elements changed their cluster assignment.
# 18
#         3 elements changed their cluster assignment.
# 19
#         3 elements changed their cluster assignment.
# 20
#         1 elements changed their cluster assignment.
# 21
# seed=000000, heterogeneity=58224.59913
# 0
# 1
#     15354 elements changed their cluster assignment.
# 2
#      2781 elements changed their cluster assignment.
# 3
#      1368 elements changed their cluster assignment.
# 4
#      1464 elements changed their cluster assignment.
# 5
#      1509 elements changed their cluster assignment.
# 6
#      1171 elements changed their cluster assignment.
# 7
#       730 elements changed their cluster assignment.
# 8
#       539 elements changed their cluster assignment.
# 9
#       490 elements changed their cluster assignment.
# 10
#       534 elements changed their cluster assignment.
# 11
#       599 elements changed their cluster assignment.
# 12
#       667 elements changed their cluster assignment.
# 13
#       743 elements changed their cluster assignment.
# 14
#       938 elements changed their cluster assignment.
# 15
#      1121 elements changed their cluster assignment.
# 16
#      1282 elements changed their cluster assignment.
# 17
#      1601 elements changed their cluster assignment.
# 18
#      1951 elements changed their cluster assignment.
# 19
#      1090 elements changed their cluster assignment.
# 20
#       307 elements changed their cluster assignment.
# 21
#       146 elements changed their cluster assignment.
# 22
#        80 elements changed their cluster assignment.
# 23
#        61 elements changed their cluster assignment.
# 24
#        34 elements changed their cluster assignment.
# 25
#        19 elements changed their cluster assignment.
# 26
#        12 elements changed their cluster assignment.
# 27
#        11 elements changed their cluster assignment.
# 28
#         9 elements changed their cluster assignment.
# 29
#         7 elements changed their cluster assignment.
# 30
#         4 elements changed their cluster assignment.
# 31
#         1 elements changed their cluster assignment.
# 32
# seed=020000, heterogeneity=58179.57453
# 0
# 1
#     14196 elements changed their cluster assignment.
# 2
#      4499 elements changed their cluster assignment.
# 3
#      2039 elements changed their cluster assignment.
# 4
#      1048 elements changed their cluster assignment.
# 5
#       992 elements changed their cluster assignment.
# 6
#      1032 elements changed their cluster assignment.
# 7
#       922 elements changed their cluster assignment.
# 8
#       704 elements changed their cluster assignment.
# 9
#       504 elements changed their cluster assignment.
# 10
#       367 elements changed their cluster assignment.
# 11
#       336 elements changed their cluster assignment.
# 12
#       301 elements changed their cluster assignment.
# 13
#       281 elements changed their cluster assignment.
# 14
#       297 elements changed their cluster assignment.
# 15
#       356 elements changed their cluster assignment.
# 16
#       469 elements changed their cluster assignment.
# 17
#       669 elements changed their cluster assignment.
# 18
#       982 elements changed their cluster assignment.
# 19
#      1257 elements changed their cluster assignment.
# 20
#      1293 elements changed their cluster assignment.
# 21
#      1365 elements changed their cluster assignment.
# 22
#      1513 elements changed their cluster assignment.
# 23
#      1832 elements changed their cluster assignment.
# 24
#      1821 elements changed their cluster assignment.
# 25
#       538 elements changed their cluster assignment.
# 26
#       219 elements changed their cluster assignment.
# 27
#       116 elements changed their cluster assignment.
# 28
#        70 elements changed their cluster assignment.
# 29
#        50 elements changed their cluster assignment.
# 30
#        24 elements changed their cluster assignment.
# 31
#        18 elements changed their cluster assignment.
# 32
#        12 elements changed their cluster assignment.
# 33
#         9 elements changed their cluster assignment.
# 34
#         7 elements changed their cluster assignment.
# 35
#         5 elements changed their cluster assignment.
# 36
#         4 elements changed their cluster assignment.
# 37
#         1 elements changed their cluster assignment.
# 38
# seed=040000, heterogeneity=58179.57453
# 0
# 1
#     16392 elements changed their cluster assignment.
# 2
#      1888 elements changed their cluster assignment.
# 3
#       726 elements changed their cluster assignment.
# 4
#       641 elements changed their cluster assignment.
# 5
#       591 elements changed their cluster assignment.
# 6
#       551 elements changed their cluster assignment.
# 7
#       544 elements changed their cluster assignment.
# 8
#       588 elements changed their cluster assignment.
# 9
#       623 elements changed their cluster assignment.
# 10
#       661 elements changed their cluster assignment.
# 11
#       756 elements changed their cluster assignment.
# 12
#       932 elements changed their cluster assignment.
# 13
#      1067 elements changed their cluster assignment.
# 14
#      1264 elements changed their cluster assignment.
# 15
#      1552 elements changed their cluster assignment.
# 16
#      1950 elements changed their cluster assignment.
# 17
#      1155 elements changed their cluster assignment.
# 18
#       319 elements changed their cluster assignment.
# 19
#       152 elements changed their cluster assignment.
# 20
#        85 elements changed their cluster assignment.
# 21
#        58 elements changed their cluster assignment.
# 22
#        37 elements changed their cluster assignment.
# 23
#        20 elements changed their cluster assignment.
# 24
#        14 elements changed their cluster assignment.
# 25
#        12 elements changed their cluster assignment.
# 26
#         8 elements changed their cluster assignment.
# 27
#         8 elements changed their cluster assignment.
# 28
#         3 elements changed their cluster assignment.
# 29
#         3 elements changed their cluster assignment.
# 30
#         1 elements changed their cluster assignment.
# 31
# seed=060000, heterogeneity=58179.57453
# 0
# 1
#     11732 elements changed their cluster assignment.
# 2
#      1275 elements changed their cluster assignment.
# 3
#       385 elements changed their cluster assignment.
# 4
#       203 elements changed their cluster assignment.
# 5
#       104 elements changed their cluster assignment.
# 6
#        60 elements changed their cluster assignment.
# 7
#        48 elements changed their cluster assignment.
# 8
#        47 elements changed their cluster assignment.
# 9
#        40 elements changed their cluster assignment.
# 10
#        38 elements changed their cluster assignment.
# 11
#        34 elements changed their cluster assignment.
# 12
#        29 elements changed their cluster assignment.
# 13
#        25 elements changed their cluster assignment.
# 14
#        27 elements changed their cluster assignment.
# 15
#        32 elements changed their cluster assignment.
# 16
#        29 elements changed their cluster assignment.
# 17
#        33 elements changed their cluster assignment.
# 18
#        40 elements changed their cluster assignment.
# 19
#        37 elements changed their cluster assignment.
# 20
#        42 elements changed their cluster assignment.
# 21
#        39 elements changed their cluster assignment.
# 22
#        47 elements changed their cluster assignment.
# 23
#        51 elements changed their cluster assignment.
# 24
#        54 elements changed their cluster assignment.
# 25
#        54 elements changed their cluster assignment.
# 26
#        59 elements changed their cluster assignment.
# 27
#        63 elements changed their cluster assignment.
# 28
#        71 elements changed their cluster assignment.
# 29
#        73 elements changed their cluster assignment.
# 30
#        74 elements changed their cluster assignment.
# 31
#        96 elements changed their cluster assignment.
# 32
#        94 elements changed their cluster assignment.
# 33
#       111 elements changed their cluster assignment.
# 34
#       139 elements changed their cluster assignment.
# 35
#       174 elements changed their cluster assignment.
# 36
#       235 elements changed their cluster assignment.
# 37
#       357 elements changed their cluster assignment.
# 38
#       468 elements changed their cluster assignment.
# 39
#       544 elements changed their cluster assignment.
# 40
#       553 elements changed their cluster assignment.
# 41
#       592 elements changed their cluster assignment.
# 42
#       497 elements changed their cluster assignment.
# 43
#       395 elements changed their cluster assignment.
# 44
#       274 elements changed their cluster assignment.
# 45
#       191 elements changed their cluster assignment.
# 46
#       143 elements changed their cluster assignment.
# 47
#        96 elements changed their cluster assignment.
# 48
#        65 elements changed their cluster assignment.
# 49
#        44 elements changed their cluster assignment.
# 50
#        43 elements changed their cluster assignment.
# 51
#        30 elements changed their cluster assignment.
# 52
#        21 elements changed their cluster assignment.
# 53
#        18 elements changed their cluster assignment.
# 54
#         9 elements changed their cluster assignment.
# 55
#         5 elements changed their cluster assignment.
# 56
#         4 elements changed their cluster assignment.
# 57
#         5 elements changed their cluster assignment.
# 58
#         4 elements changed their cluster assignment.
# 59
#         4 elements changed their cluster assignment.
# 60
#         2 elements changed their cluster assignment.
# 61
#         2 elements changed their cluster assignment.
# 62
# seed=080000, heterogeneity=58224.59952
# 0
# 1
#     13155 elements changed their cluster assignment.
# 2
#      2540 elements changed their cluster assignment.
# 3
#       699 elements changed their cluster assignment.
# 4
#       414 elements changed their cluster assignment.
# 5
#       359 elements changed their cluster assignment.
# 6
#       338 elements changed their cluster assignment.
# 7
#       395 elements changed their cluster assignment.
# 8
#       545 elements changed their cluster assignment.
# 9
#       766 elements changed their cluster assignment.
# 10
#      1107 elements changed their cluster assignment.
# 11
#      1319 elements changed their cluster assignment.
# 12
#      1364 elements changed their cluster assignment.
# 13
#      1490 elements changed their cluster assignment.
# 14
#      1689 elements changed their cluster assignment.
# 15
#      2011 elements changed their cluster assignment.
# 16
#      1049 elements changed their cluster assignment.
# 17
#       298 elements changed their cluster assignment.
# 18
#       150 elements changed their cluster assignment.
# 19
#        84 elements changed their cluster assignment.
# 20
#        57 elements changed their cluster assignment.
# 21
#        37 elements changed their cluster assignment.
# 22
#        20 elements changed their cluster assignment.
# 23
#        14 elements changed their cluster assignment.
# 24
#        12 elements changed their cluster assignment.
# 25
#         8 elements changed their cluster assignment.
# 26
#         8 elements changed their cluster assignment.
# 27
#         3 elements changed their cluster assignment.
# 28
#         3 elements changed their cluster assignment.
# 29
#         1 elements changed their cluster assignment.
# 30
# seed=100000, heterogeneity=58179.57453
# 0
# 1
#     13513 elements changed their cluster assignment.
# 2
#      2339 elements changed their cluster assignment.
# 3
#       822 elements changed their cluster assignment.
# 4
#       619 elements changed their cluster assignment.
# 5
#       530 elements changed their cluster assignment.
# 6
#       516 elements changed their cluster assignment.
# 7
#       558 elements changed their cluster assignment.
# 8
#       593 elements changed their cluster assignment.
# 9
#       667 elements changed their cluster assignment.
# 10
#       741 elements changed their cluster assignment.
# 11
#       916 elements changed their cluster assignment.
# 12
#      1072 elements changed their cluster assignment.
# 13
#      1244 elements changed their cluster assignment.
# 14
#      1543 elements changed their cluster assignment.
# 15
#      1935 elements changed their cluster assignment.
# 16
#      1289 elements changed their cluster assignment.
# 17
#       339 elements changed their cluster assignment.
# 18
#       155 elements changed their cluster assignment.
# 19
#        87 elements changed their cluster assignment.
# 20
#        60 elements changed their cluster assignment.
# 21
#        37 elements changed their cluster assignment.
# 22
#        20 elements changed their cluster assignment.
# 23
#        14 elements changed their cluster assignment.
# 24
#        12 elements changed their cluster assignment.
# 25
#         8 elements changed their cluster assignment.
# 26
#         8 elements changed their cluster assignment.
# 27
#         3 elements changed their cluster assignment.
# 28
#         3 elements changed their cluster assignment.
# 29
#         1 elements changed their cluster assignment.
# 30
# seed=120000, heterogeneity=58179.57453
# 0
# 1
#     24631 elements changed their cluster assignment.
# 2
#      8154 elements changed their cluster assignment.
# 3
#      4568 elements changed their cluster assignment.
# 4
#      2699 elements changed their cluster assignment.
# 5
#      1999 elements changed their cluster assignment.
# 6
#      2051 elements changed their cluster assignment.
# 7
#      2661 elements changed their cluster assignment.
# 8
#      3117 elements changed their cluster assignment.
# 9
#      2378 elements changed their cluster assignment.
# 10
#      1288 elements changed their cluster assignment.
# 11
#       651 elements changed their cluster assignment.
# 12
#       383 elements changed their cluster assignment.
# 13
#       283 elements changed their cluster assignment.
# 14
#       234 elements changed their cluster assignment.
# 15
#       217 elements changed their cluster assignment.
# 16
#       220 elements changed their cluster assignment.
# 17
#       181 elements changed their cluster assignment.
# 18
#       163 elements changed their cluster assignment.
# 19
#       135 elements changed their cluster assignment.
# 20
#       119 elements changed their cluster assignment.
# 21
#       123 elements changed their cluster assignment.
# 22
#       112 elements changed their cluster assignment.
# 23
#       108 elements changed their cluster assignment.
# 24
#        85 elements changed their cluster assignment.
# 25
#        82 elements changed their cluster assignment.
# 26
#        85 elements changed their cluster assignment.
# 27
#        74 elements changed their cluster assignment.
# 28
#        56 elements changed their cluster assignment.
# 29
#        73 elements changed their cluster assignment.
# 30
#        64 elements changed their cluster assignment.
# 31
#        57 elements changed their cluster assignment.
# 32
#        49 elements changed their cluster assignment.
# 33
#        50 elements changed their cluster assignment.
# 34
#        35 elements changed their cluster assignment.
# 35
#        32 elements changed their cluster assignment.
# 36
#        30 elements changed their cluster assignment.
# 37
#        31 elements changed their cluster assignment.
# 38
#        27 elements changed their cluster assignment.
# 39
#        28 elements changed their cluster assignment.
# 40
#        31 elements changed their cluster assignment.
# 41
#        44 elements changed their cluster assignment.
# 42
#        31 elements changed their cluster assignment.
# 43
#         9 elements changed their cluster assignment.
# 44
#         5 elements changed their cluster assignment.
# 45
#         2 elements changed their cluster assignment.
# 46
# seed=000000, heterogeneity=57441.33298
# 0
# 1
#     26028 elements changed their cluster assignment.
# 2
#      8318 elements changed their cluster assignment.
# 3
#      4771 elements changed their cluster assignment.
# 4
#      4303 elements changed their cluster assignment.
# 5
#      4017 elements changed their cluster assignment.
# 6
#      3394 elements changed their cluster assignment.
# 7
#      3233 elements changed their cluster assignment.
# 8
#      2524 elements changed their cluster assignment.
# 9
#      1679 elements changed their cluster assignment.
# 10
#      1213 elements changed their cluster assignment.
# 11
#      1027 elements changed their cluster assignment.
# 12
#       866 elements changed their cluster assignment.
# 13
#       756 elements changed their cluster assignment.
# 14
#       584 elements changed their cluster assignment.
# 15
#       381 elements changed their cluster assignment.
# 16
#       247 elements changed their cluster assignment.
# 17
#       163 elements changed their cluster assignment.
# 18
#        97 elements changed their cluster assignment.
# 19
#        73 elements changed their cluster assignment.
# 20
#        49 elements changed their cluster assignment.
# 21
#        41 elements changed their cluster assignment.
# 22
#        29 elements changed their cluster assignment.
# 23
#        24 elements changed their cluster assignment.
# 24
#        17 elements changed their cluster assignment.
# 25
#         5 elements changed their cluster assignment.
# 26
# seed=020000, heterogeneity=57457.50383
# 0
# 1
#     25242 elements changed their cluster assignment.
# 2
#      8989 elements changed their cluster assignment.
# 3
#      4345 elements changed their cluster assignment.
# 4
#      2234 elements changed their cluster assignment.
# 5
#      1381 elements changed their cluster assignment.
# 6
#       956 elements changed their cluster assignment.
# 7
#       682 elements changed their cluster assignment.
# 8
#       583 elements changed their cluster assignment.
# 9
#       542 elements changed their cluster assignment.
# 10
#       397 elements changed their cluster assignment.
# 11
#       328 elements changed their cluster assignment.
# 12
#       315 elements changed their cluster assignment.
# 13
#       352 elements changed their cluster assignment.
# 14
#       451 elements changed their cluster assignment.
# 15
#       592 elements changed their cluster assignment.
# 16
#       558 elements changed their cluster assignment.
# 17
#       572 elements changed their cluster assignment.
# 18
#       509 elements changed their cluster assignment.
# 19
#       473 elements changed their cluster assignment.
# 20
#       448 elements changed their cluster assignment.
# 21
#       391 elements changed their cluster assignment.
# 22
#       374 elements changed their cluster assignment.
# 23
#       324 elements changed their cluster assignment.
# 24
#       284 elements changed their cluster assignment.
# 25
#       262 elements changed their cluster assignment.
# 26
#       245 elements changed their cluster assignment.
# 27
#       207 elements changed their cluster assignment.
# 28
#       192 elements changed their cluster assignment.
# 29
#       169 elements changed their cluster assignment.
# 30
#       146 elements changed their cluster assignment.
# 31
#       162 elements changed their cluster assignment.
# 32
#       195 elements changed their cluster assignment.
# 33
#       187 elements changed their cluster assignment.
# 34
#       126 elements changed their cluster assignment.
# 35
#        71 elements changed their cluster assignment.
# 36
#        39 elements changed their cluster assignment.
# 37
#        22 elements changed their cluster assignment.
# 38
#        10 elements changed their cluster assignment.
# 39
#        10 elements changed their cluster assignment.
# 40
#         6 elements changed their cluster assignment.
# 41
#         3 elements changed their cluster assignment.
# 42
# seed=040000, heterogeneity=57469.82237
# 0
# 1
#     26207 elements changed their cluster assignment.
# 2
#      9383 elements changed their cluster assignment.
# 3
#      5288 elements changed their cluster assignment.
# 4
#      3099 elements changed their cluster assignment.
# 5
#      2860 elements changed their cluster assignment.
# 6
#      3267 elements changed their cluster assignment.
# 7
#      3269 elements changed their cluster assignment.
# 8
#      2528 elements changed their cluster assignment.
# 9
#      1691 elements changed their cluster assignment.
# 10
#      1246 elements changed their cluster assignment.
# 11
#      1037 elements changed their cluster assignment.
# 12
#      1158 elements changed their cluster assignment.
# 13
#      1767 elements changed their cluster assignment.
# 14
#      2622 elements changed their cluster assignment.
# 15
#      2452 elements changed their cluster assignment.
# 16
#      1379 elements changed their cluster assignment.
# 17
#       640 elements changed their cluster assignment.
# 18
#       311 elements changed their cluster assignment.
# 19
#       184 elements changed their cluster assignment.
# 20
#       140 elements changed their cluster assignment.
# 21
#        94 elements changed their cluster assignment.
# 22
#        77 elements changed their cluster assignment.
# 23
#        62 elements changed their cluster assignment.
# 24
#        46 elements changed their cluster assignment.
# 25
#        48 elements changed their cluster assignment.
# 26
#        52 elements changed their cluster assignment.
# 27
#        36 elements changed their cluster assignment.
# 28
#        37 elements changed their cluster assignment.
# 29
#        25 elements changed their cluster assignment.
# 30
#        27 elements changed their cluster assignment.
# 31
#        24 elements changed their cluster assignment.
# 32
#        21 elements changed their cluster assignment.
# 33
#        26 elements changed their cluster assignment.
# 34
#        28 elements changed their cluster assignment.
# 35
#        36 elements changed their cluster assignment.
# 36
#        31 elements changed their cluster assignment.
# 37
#        21 elements changed their cluster assignment.
# 38
#        23 elements changed their cluster assignment.
# 39
#        34 elements changed their cluster assignment.
# 40
#        25 elements changed their cluster assignment.
# 41
#        25 elements changed their cluster assignment.
# 42
#        25 elements changed their cluster assignment.
# 43
#        19 elements changed their cluster assignment.
# 44
#        12 elements changed their cluster assignment.
# 45
#        15 elements changed their cluster assignment.
# 46
#        17 elements changed their cluster assignment.
# 47
#        22 elements changed their cluster assignment.
# 48
#        22 elements changed their cluster assignment.
# 49
#        23 elements changed their cluster assignment.
# 50
#        27 elements changed their cluster assignment.
# 51
#        33 elements changed their cluster assignment.
# 52
#        38 elements changed their cluster assignment.
# 53
#        34 elements changed their cluster assignment.
# 54
#        36 elements changed their cluster assignment.
# 55
#        36 elements changed their cluster assignment.
# 56
#        43 elements changed their cluster assignment.
# 57
#        49 elements changed their cluster assignment.
# 58
#        57 elements changed their cluster assignment.
# 59
#        66 elements changed their cluster assignment.
# 60
#        81 elements changed their cluster assignment.
# 61
#       103 elements changed their cluster assignment.
# 62
#       110 elements changed their cluster assignment.
# 63
#       112 elements changed their cluster assignment.
# 64
#       140 elements changed their cluster assignment.
# 65
#       176 elements changed their cluster assignment.
# 66
#       219 elements changed their cluster assignment.
# 67
#       321 elements changed their cluster assignment.
# 68
#       462 elements changed their cluster assignment.
# 69
#       575 elements changed their cluster assignment.
# 70
#       552 elements changed their cluster assignment.
# 71
#       391 elements changed their cluster assignment.
# 72
#       205 elements changed their cluster assignment.
# 73
#       141 elements changed their cluster assignment.
# 74
#        97 elements changed their cluster assignment.
# 75
#        77 elements changed their cluster assignment.
# 76
#        69 elements changed their cluster assignment.
# 77
#        55 elements changed their cluster assignment.
# 78
#        43 elements changed their cluster assignment.
# 79
#        34 elements changed their cluster assignment.
# 80
#        25 elements changed their cluster assignment.
# 81
#        24 elements changed their cluster assignment.
# 82
#        24 elements changed their cluster assignment.
# 83
#        23 elements changed their cluster assignment.
# 84
#        16 elements changed their cluster assignment.
# 85
#        10 elements changed their cluster assignment.
# 86
#        14 elements changed their cluster assignment.
# 87
#        11 elements changed their cluster assignment.
# 88
#        11 elements changed their cluster assignment.
# 89
#        11 elements changed their cluster assignment.
# 90
#         8 elements changed their cluster assignment.
# 91
#        14 elements changed their cluster assignment.
# 92
#        14 elements changed their cluster assignment.
# 93
#        11 elements changed their cluster assignment.
# 94
#        12 elements changed their cluster assignment.
# 95
#        18 elements changed their cluster assignment.
# 96
#        23 elements changed their cluster assignment.
# 97
#        28 elements changed their cluster assignment.
# 98
#        21 elements changed their cluster assignment.
# 99
#        29 elements changed their cluster assignment.
# 100
#        41 elements changed their cluster assignment.
# 101
#        60 elements changed their cluster assignment.
# 102
#        67 elements changed their cluster assignment.
# 103
#        71 elements changed their cluster assignment.
# 104
#        72 elements changed their cluster assignment.
# 105
#        61 elements changed their cluster assignment.
# 106
#        65 elements changed their cluster assignment.
# 107
#        58 elements changed their cluster assignment.
# 108
#        47 elements changed their cluster assignment.
# 109
#        47 elements changed their cluster assignment.
# 110
#        38 elements changed their cluster assignment.
# 111
#        28 elements changed their cluster assignment.
# 112
#        28 elements changed their cluster assignment.
# 113
#        34 elements changed their cluster assignment.
# 114
#        37 elements changed their cluster assignment.
# 115
#        30 elements changed their cluster assignment.
# 116
#        22 elements changed their cluster assignment.
# 117
#        11 elements changed their cluster assignment.
# 118
#         9 elements changed their cluster assignment.
# 119
#         4 elements changed their cluster assignment.
# 120
#         2 elements changed their cluster assignment.
# 121
#         1 elements changed their cluster assignment.
# 122
#         1 elements changed their cluster assignment.
# 123
#         1 elements changed their cluster assignment.
# 124
#         2 elements changed their cluster assignment.
# 125
#         6 elements changed their cluster assignment.
# 126
#         5 elements changed their cluster assignment.
# 127
#         1 elements changed their cluster assignment.
# 128
# seed=060000, heterogeneity=57503.05355
# 0
# 1
#     27154 elements changed their cluster assignment.
# 2
#     11989 elements changed their cluster assignment.
# 3
#      6588 elements changed their cluster assignment.
# 4
#      3409 elements changed their cluster assignment.
# 5
#      1732 elements changed their cluster assignment.
# 6
#      1098 elements changed their cluster assignment.
# 7
#       769 elements changed their cluster assignment.
# 8
#       572 elements changed their cluster assignment.
# 9
#       441 elements changed their cluster assignment.
# 10
#       370 elements changed their cluster assignment.
# 11
#       325 elements changed their cluster assignment.
# 12
#       317 elements changed their cluster assignment.
# 13
#       354 elements changed their cluster assignment.
# 14
#       314 elements changed their cluster assignment.
# 15
#       235 elements changed their cluster assignment.
# 16
#       188 elements changed their cluster assignment.
# 17
#       178 elements changed their cluster assignment.
# 18
#       165 elements changed their cluster assignment.
# 19
#       164 elements changed their cluster assignment.
# 20
#       189 elements changed their cluster assignment.
# 21
#       194 elements changed their cluster assignment.
# 22
#       200 elements changed their cluster assignment.
# 23
#       187 elements changed their cluster assignment.
# 24
#       201 elements changed their cluster assignment.
# 25
#       170 elements changed their cluster assignment.
# 26
#       133 elements changed their cluster assignment.
# 27
#       135 elements changed their cluster assignment.
# 28
#       139 elements changed their cluster assignment.
# 29
#       130 elements changed their cluster assignment.
# 30
#       113 elements changed their cluster assignment.
# 31
#       104 elements changed their cluster assignment.
# 32
#        88 elements changed their cluster assignment.
# 33
#        80 elements changed their cluster assignment.
# 34
#        62 elements changed their cluster assignment.
# 35
#        59 elements changed their cluster assignment.
# 36
#        51 elements changed their cluster assignment.
# 37
#        54 elements changed their cluster assignment.
# 38
#        46 elements changed their cluster assignment.
# 39
#        46 elements changed their cluster assignment.
# 40
#        36 elements changed their cluster assignment.
# 41
#        27 elements changed their cluster assignment.
# 42
#        24 elements changed their cluster assignment.
# 43
#        31 elements changed their cluster assignment.
# 44
#        29 elements changed their cluster assignment.
# 45
#        24 elements changed their cluster assignment.
# 46
#        25 elements changed their cluster assignment.
# 47
#        35 elements changed their cluster assignment.
# 48
#        49 elements changed their cluster assignment.
# 49
#        36 elements changed their cluster assignment.
# 50
#        18 elements changed their cluster assignment.
# 51
#         9 elements changed their cluster assignment.
# 52
#         5 elements changed their cluster assignment.
# 53
#         7 elements changed their cluster assignment.
# 54
#         3 elements changed their cluster assignment.
# 55
#         1 elements changed their cluster assignment.
# 56
#         1 elements changed their cluster assignment.
# 57
# seed=080000, heterogeneity=57464.05684
# 0
# 1
#     27077 elements changed their cluster assignment.
# 2
#      9329 elements changed their cluster assignment.
# 3
#      4812 elements changed their cluster assignment.
# 4
#      2547 elements changed their cluster assignment.
# 5
#      1767 elements changed their cluster assignment.
# 6
#      1659 elements changed their cluster assignment.
# 7
#      1807 elements changed their cluster assignment.
# 8
#      2092 elements changed their cluster assignment.
# 9
#      2323 elements changed their cluster assignment.
# 10
#      2102 elements changed their cluster assignment.
# 11
#      1547 elements changed their cluster assignment.
# 12
#      1062 elements changed their cluster assignment.
# 13
#       755 elements changed their cluster assignment.
# 14
#       571 elements changed their cluster assignment.
# 15
#       411 elements changed their cluster assignment.
# 16
#       336 elements changed their cluster assignment.
# 17
#       299 elements changed their cluster assignment.
# 18
#       262 elements changed their cluster assignment.
# 19
#       248 elements changed their cluster assignment.
# 20
#       231 elements changed their cluster assignment.
# 21
#       212 elements changed their cluster assignment.
# 22
#       207 elements changed their cluster assignment.
# 23
#       228 elements changed their cluster assignment.
# 24
#       271 elements changed their cluster assignment.
# 25
#       285 elements changed their cluster assignment.
# 26
#       305 elements changed their cluster assignment.
# 27
#       315 elements changed their cluster assignment.
# 28
#       260 elements changed their cluster assignment.
# 29
#       200 elements changed their cluster assignment.
# 30
#       132 elements changed their cluster assignment.
# 31
#       104 elements changed their cluster assignment.
# 32
#       103 elements changed their cluster assignment.
# 33
#        95 elements changed their cluster assignment.
# 34
#        99 elements changed their cluster assignment.
# 35
#       110 elements changed their cluster assignment.
# 36
#       133 elements changed their cluster assignment.
# 37
#       171 elements changed their cluster assignment.
# 38
#       200 elements changed their cluster assignment.
# 39
#       206 elements changed their cluster assignment.
# 40
#       183 elements changed their cluster assignment.
# 41
#       141 elements changed their cluster assignment.
# 42
#       125 elements changed their cluster assignment.
# 43
#       116 elements changed their cluster assignment.
# 44
#        94 elements changed their cluster assignment.
# 45
#        82 elements changed their cluster assignment.
# 46
#        83 elements changed their cluster assignment.
# 47
#        57 elements changed their cluster assignment.
# 48
#        63 elements changed their cluster assignment.
# 49
#        59 elements changed their cluster assignment.
# 50
#        52 elements changed their cluster assignment.
# 51
#        54 elements changed their cluster assignment.
# 52
#        54 elements changed their cluster assignment.
# 53
#        47 elements changed their cluster assignment.
# 54
#        45 elements changed their cluster assignment.
# 55
#        34 elements changed their cluster assignment.
# 56
#        29 elements changed their cluster assignment.
# 57
#        31 elements changed their cluster assignment.
# 58
#        39 elements changed their cluster assignment.
# 59
#        44 elements changed their cluster assignment.
# 60
#        48 elements changed their cluster assignment.
# 61
#        50 elements changed their cluster assignment.
# 62
#        51 elements changed their cluster assignment.
# 63
#        53 elements changed their cluster assignment.
# 64
#        74 elements changed their cluster assignment.
# 65
#        75 elements changed their cluster assignment.
# 66
#        74 elements changed their cluster assignment.
# 67
#        45 elements changed their cluster assignment.
# 68
#        34 elements changed their cluster assignment.
# 69
#        29 elements changed their cluster assignment.
# 70
#        21 elements changed their cluster assignment.
# 71
#        19 elements changed their cluster assignment.
# 72
#        25 elements changed their cluster assignment.
# 73
#        20 elements changed their cluster assignment.
# 74
#        18 elements changed their cluster assignment.
# 75
#        13 elements changed their cluster assignment.
# 76
#        10 elements changed their cluster assignment.
# 77
#         7 elements changed their cluster assignment.
# 78
#         5 elements changed their cluster assignment.
# 79
#         6 elements changed their cluster assignment.
# 80
#         2 elements changed their cluster assignment.
# 81
# seed=100000, heterogeneity=57487.57010
# 0
# 1
#     23796 elements changed their cluster assignment.
# 2
#      9286 elements changed their cluster assignment.
# 3
#      3495 elements changed their cluster assignment.
# 4
#      1770 elements changed their cluster assignment.
# 5
#      1231 elements changed their cluster assignment.
# 6
#       972 elements changed their cluster assignment.
# 7
#       743 elements changed their cluster assignment.
# 8
#       509 elements changed their cluster assignment.
# 9
#       326 elements changed their cluster assignment.
# 10
#       264 elements changed their cluster assignment.
# 11
#       242 elements changed their cluster assignment.
# 12
#       224 elements changed their cluster assignment.
# 13
#       201 elements changed their cluster assignment.
# 14
#       159 elements changed their cluster assignment.
# 15
#        90 elements changed their cluster assignment.
# 16
#        49 elements changed their cluster assignment.
# 17
#        35 elements changed their cluster assignment.
# 18
#        24 elements changed their cluster assignment.
# 19
#        12 elements changed their cluster assignment.
# 20
#         7 elements changed their cluster assignment.
# 21
#         7 elements changed their cluster assignment.
# 22
#         3 elements changed their cluster assignment.
# 23
#         3 elements changed their cluster assignment.
# 24
#         5 elements changed their cluster assignment.
# 25
#         1 elements changed their cluster assignment.
# 26
# seed=120000, heterogeneity=57534.79120
# 0
# 1
#     24423 elements changed their cluster assignment.
# 2
#     10494 elements changed their cluster assignment.
# 3
#      6001 elements changed their cluster assignment.
# 4
#      3477 elements changed their cluster assignment.
# 5
#      1921 elements changed their cluster assignment.
# 6
#      1277 elements changed their cluster assignment.
# 7
#       982 elements changed their cluster assignment.
# 8
#       933 elements changed their cluster assignment.
# 9
#       943 elements changed their cluster assignment.
# 10
#       922 elements changed their cluster assignment.
# 11
#       837 elements changed their cluster assignment.
# 12
#       750 elements changed their cluster assignment.
# 13
#       653 elements changed their cluster assignment.
# 14
#       491 elements changed their cluster assignment.
# 15
#       319 elements changed their cluster assignment.
# 16
#       247 elements changed their cluster assignment.
# 17
#       222 elements changed their cluster assignment.
# 18
#       220 elements changed their cluster assignment.
# 19
#       237 elements changed their cluster assignment.
# 20
#       269 elements changed their cluster assignment.
# 21
#       315 elements changed their cluster assignment.
# 22
#       270 elements changed their cluster assignment.
# 23
#       229 elements changed their cluster assignment.
# 24
#       173 elements changed their cluster assignment.
# 25
#       139 elements changed their cluster assignment.
# 26
#       128 elements changed their cluster assignment.
# 27
#       133 elements changed their cluster assignment.
# 28
#       137 elements changed their cluster assignment.
# 29
#       167 elements changed their cluster assignment.
# 30
#       191 elements changed their cluster assignment.
# 31
#       229 elements changed their cluster assignment.
# 32
#       278 elements changed their cluster assignment.
# 33
#       261 elements changed their cluster assignment.
# 34
#       218 elements changed their cluster assignment.
# 35
#       167 elements changed their cluster assignment.
# 36
#       135 elements changed their cluster assignment.
# 37
#        95 elements changed their cluster assignment.
# 38
#        62 elements changed their cluster assignment.
# 39
#        32 elements changed their cluster assignment.
# 40
#        26 elements changed their cluster assignment.
# 41
#        22 elements changed their cluster assignment.
# 42
#        20 elements changed their cluster assignment.
# 43
#        14 elements changed their cluster assignment.
# 44
#        10 elements changed their cluster assignment.
# 45
#        10 elements changed their cluster assignment.
# 46
#         6 elements changed their cluster assignment.
# 47
#         5 elements changed their cluster assignment.
# 48
#         3 elements changed their cluster assignment.
# 49
#         5 elements changed their cluster assignment.
# 50
#         4 elements changed their cluster assignment.
# 51
#         1 elements changed their cluster assignment.
# 52
# seed=000000, heterogeneity=56828.55406
# 0
# 1
#     24450 elements changed their cluster assignment.
# 2
#      8704 elements changed their cluster assignment.
# 3
#      4604 elements changed their cluster assignment.
# 4
#      3138 elements changed their cluster assignment.
# 5
#      2958 elements changed their cluster assignment.
# 6
#      2991 elements changed their cluster assignment.
# 7
#      2202 elements changed their cluster assignment.
# 8
#      1448 elements changed their cluster assignment.
# 9
#       945 elements changed their cluster assignment.
# 10
#       644 elements changed their cluster assignment.
# 11
#       545 elements changed their cluster assignment.
# 12
#       487 elements changed their cluster assignment.
# 13
#       413 elements changed their cluster assignment.
# 14
#       326 elements changed their cluster assignment.
# 15
#       278 elements changed their cluster assignment.
# 16
#       223 elements changed their cluster assignment.
# 17
#       168 elements changed their cluster assignment.
# 18
#       116 elements changed their cluster assignment.
# 19
#        85 elements changed their cluster assignment.
# 20
#        69 elements changed their cluster assignment.
# 21
#        51 elements changed their cluster assignment.
# 22
#        37 elements changed their cluster assignment.
# 23
#        28 elements changed their cluster assignment.
# 24
#        17 elements changed their cluster assignment.
# 25
#        14 elements changed their cluster assignment.
# 26
#        15 elements changed their cluster assignment.
# 27
#        13 elements changed their cluster assignment.
# 28
#        12 elements changed their cluster assignment.
# 29
#         8 elements changed their cluster assignment.
# 30
#         3 elements changed their cluster assignment.
# 31
#         3 elements changed their cluster assignment.
# 32
#         4 elements changed their cluster assignment.
# 33
#         1 elements changed their cluster assignment.
# 34
# seed=020000, heterogeneity=56943.91794
# 0
# 1
#     24766 elements changed their cluster assignment.
# 2
#     10621 elements changed their cluster assignment.
# 3
#      5819 elements changed their cluster assignment.
# 4
#      3718 elements changed their cluster assignment.
# 5
#      3040 elements changed their cluster assignment.
# 6
#      2616 elements changed their cluster assignment.
# 7
#      2177 elements changed their cluster assignment.
# 8
#      2035 elements changed their cluster assignment.
# 9
#      1829 elements changed their cluster assignment.
# 10
#      1519 elements changed their cluster assignment.
# 11
#      1225 elements changed their cluster assignment.
# 12
#       908 elements changed their cluster assignment.
# 13
#       636 elements changed their cluster assignment.
# 14
#       448 elements changed their cluster assignment.
# 15
#       366 elements changed their cluster assignment.
# 16
#       256 elements changed their cluster assignment.
# 17
#       195 elements changed their cluster assignment.
# 18
#       146 elements changed their cluster assignment.
# 19
#       118 elements changed their cluster assignment.
# 20
#       115 elements changed their cluster assignment.
# 21
#       132 elements changed their cluster assignment.
# 22
#       156 elements changed their cluster assignment.
# 23
#       157 elements changed their cluster assignment.
# 24
#       177 elements changed their cluster assignment.
# 25
#       222 elements changed their cluster assignment.
# 26
#       297 elements changed their cluster assignment.
# 27
#       432 elements changed their cluster assignment.
# 28
#       347 elements changed their cluster assignment.
# 29
#       175 elements changed their cluster assignment.
# 30
#        75 elements changed their cluster assignment.
# 31
#        33 elements changed their cluster assignment.
# 32
#        17 elements changed their cluster assignment.
# 33
#        13 elements changed their cluster assignment.
# 34
#         5 elements changed their cluster assignment.
# 35
#         6 elements changed their cluster assignment.
# 36
#         5 elements changed their cluster assignment.
# 37
#         3 elements changed their cluster assignment.
# 38
#         1 elements changed their cluster assignment.
# 39
#         1 elements changed their cluster assignment.
# 40
#         2 elements changed their cluster assignment.
# 41
# seed=040000, heterogeneity=56816.94257
# 0
# 1
#     26638 elements changed their cluster assignment.
# 2
#     10126 elements changed their cluster assignment.
# 3
#      5634 elements changed their cluster assignment.
# 4
#      3673 elements changed their cluster assignment.
# 5
#      2368 elements changed their cluster assignment.
# 6
#      1612 elements changed their cluster assignment.
# 7
#      1045 elements changed their cluster assignment.
# 8
#       689 elements changed their cluster assignment.
# 9
#       527 elements changed their cluster assignment.
# 10
#       401 elements changed their cluster assignment.
# 11
#       264 elements changed their cluster assignment.
# 12
#       208 elements changed their cluster assignment.
# 13
#       185 elements changed their cluster assignment.
# 14
#       153 elements changed their cluster assignment.
# 15
#        91 elements changed their cluster assignment.
# 16
#        65 elements changed their cluster assignment.
# 17
#        49 elements changed their cluster assignment.
# 18
#        39 elements changed their cluster assignment.
# 19
#        28 elements changed their cluster assignment.
# 20
#        25 elements changed their cluster assignment.
# 21
#        21 elements changed their cluster assignment.
# 22
#        17 elements changed their cluster assignment.
# 23
#        11 elements changed their cluster assignment.
# 24
#         8 elements changed their cluster assignment.
# 25
#         5 elements changed their cluster assignment.
# 26
#         5 elements changed their cluster assignment.
# 27
#         5 elements changed their cluster assignment.
# 28
#         3 elements changed their cluster assignment.
# 29
#         1 elements changed their cluster assignment.
# 30
#         1 elements changed their cluster assignment.
# 31
#         2 elements changed their cluster assignment.
# 32
# seed=060000, heterogeneity=56920.95767
# 0
# 1
#     23457 elements changed their cluster assignment.
# 2
#      9378 elements changed their cluster assignment.
# 3
#      6100 elements changed their cluster assignment.
# 4
#      4056 elements changed their cluster assignment.
# 5
#      2750 elements changed their cluster assignment.
# 6
#      1906 elements changed their cluster assignment.
# 7
#      1501 elements changed their cluster assignment.
# 8
#      1267 elements changed their cluster assignment.
# 9
#      1013 elements changed their cluster assignment.
# 10
#       734 elements changed their cluster assignment.
# 11
#       559 elements changed their cluster assignment.
# 12
#       441 elements changed their cluster assignment.
# 13
#       390 elements changed their cluster assignment.
# 14
#       370 elements changed their cluster assignment.
# 15
#       377 elements changed their cluster assignment.
# 16
#       397 elements changed their cluster assignment.
# 17
#       418 elements changed their cluster assignment.
# 18
#       355 elements changed their cluster assignment.
# 19
#       288 elements changed their cluster assignment.
# 20
#       199 elements changed their cluster assignment.
# 21
#       159 elements changed their cluster assignment.
# 22
#       127 elements changed their cluster assignment.
# 23
#       108 elements changed their cluster assignment.
# 24
#        91 elements changed their cluster assignment.
# 25
#        54 elements changed their cluster assignment.
# 26
#        44 elements changed their cluster assignment.
# 27
#        38 elements changed their cluster assignment.
# 28
#        37 elements changed their cluster assignment.
# 29
#        28 elements changed their cluster assignment.
# 30
#        20 elements changed their cluster assignment.
# 31
#        19 elements changed their cluster assignment.
# 32
#        30 elements changed their cluster assignment.
# 33
#        33 elements changed their cluster assignment.
# 34
#        53 elements changed their cluster assignment.
# 35
#        66 elements changed their cluster assignment.
# 36
#        98 elements changed their cluster assignment.
# 37
#       132 elements changed their cluster assignment.
# 38
#       162 elements changed their cluster assignment.
# 39
#       181 elements changed their cluster assignment.
# 40
#       182 elements changed their cluster assignment.
# 41
#       138 elements changed their cluster assignment.
# 42
#        88 elements changed their cluster assignment.
# 43
#        76 elements changed their cluster assignment.
# 44
#        68 elements changed their cluster assignment.
# 45
#        32 elements changed their cluster assignment.
# 46
#        18 elements changed their cluster assignment.
# 47
#        17 elements changed their cluster assignment.
# 48
#        10 elements changed their cluster assignment.
# 49
#        10 elements changed their cluster assignment.
# 50
#         4 elements changed their cluster assignment.
# 51
#         1 elements changed their cluster assignment.
# 52
#         3 elements changed their cluster assignment.
# 53
#         4 elements changed their cluster assignment.
# 54
#         1 elements changed their cluster assignment.
# 55
# ...
# 85
# seed=000000, heterogeneity=56339.57044
# 0
# 1
#     25454 elements changed their cluster assignment.
# 2
#     10748 elements changed their cluster assignment.
# 3
#      5874 elements changed their cluster assignment.
# 4
#      3893 elements changed their cluster assignment.
# 5
#      2737 elements changed their cluster assignment.
# 6
#      2422 elements changed their cluster assignment.
# 7
#      2067 elements changed their cluster assignment.
# 8
#      1419 elements changed their cluster assignment.
# 9
#      1150 elements changed their cluster assignment.
# 10
#       889 elements changed their cluster assignment.
# 11
#       608 elements changed their cluster assignment.
# 12
#       432 elements changed their cluster assignment.
# 13
#       325 elements changed their cluster assignment.
# 14
#       214 elements changed their cluster assignment.
# 15
#       166 elements changed their cluster assignment.
# 16
#       126 elements changed their cluster assignment.
# 17
#       108 elements changed their cluster assignment.
# 18
#        88 elements changed their cluster assignment.
# 19
#        64 elements changed their cluster assignment.
# 20
#        41 elements changed their cluster assignment.
# 21
#        35 elements changed their cluster assignment.
# 22
#        36 elements changed their cluster assignment.
# 23
#        28 elements changed their cluster assignment.
# 24
#        33 elements changed their cluster assignment.
# 25
#        43 elements changed their cluster assignment.
# 26
#        37 elements changed their cluster assignment.
# 27
#        33 elements changed their cluster assignment.
# 28
#        44 elements changed their cluster assignment.
# 29
#        40 elements changed their cluster assignment.
# 30
#        28 elements changed their cluster assignment.
# 31
#        29 elements changed their cluster assignment.
# 32
#        30 elements changed their cluster assignment.
# 33
#        41 elements changed their cluster assignment.
# 34
#        38 elements changed their cluster assignment.
# 35
#        43 elements changed their cluster assignment.
# 36
#        52 elements changed their cluster assignment.
# 37
#        54 elements changed their cluster assignment.
# 38
#        60 elements changed their cluster assignment.
# 39
#        64 elements changed their cluster assignment.
# 40
#        71 elements changed their cluster assignment.
# 41
#        75 elements changed their cluster assignment.
# 42
#        94 elements changed their cluster assignment.
# 43
#       108 elements changed their cluster assignment.
# 44
#       151 elements changed their cluster assignment.
# 45
#       198 elements changed their cluster assignment.
# 46
#       212 elements changed their cluster assignment.
# 47
#       227 elements changed their cluster assignment.
# 48
#       254 elements changed their cluster assignment.
# 49
#       283 elements changed their cluster assignment.
# 50
#       278 elements changed their cluster assignment.
# 51
#       270 elements changed their cluster assignment.
# 52
#       204 elements changed their cluster assignment.
# 53
#       150 elements changed their cluster assignment.
# 54
#       111 elements changed their cluster assignment.
# 55
#        81 elements changed their cluster assignment.
# 56
#        61 elements changed their cluster assignment.
# 57
#        45 elements changed their cluster assignment.
# 58
#        49 elements changed their cluster assignment.
# 59
#        46 elements changed their cluster assignment.
# 60
#        35 elements changed their cluster assignment.
# 61
#        26 elements changed their cluster assignment.
# 62
#        23 elements changed their cluster assignment.
# 63
#         7 elements changed their cluster assignment.
# 64
#         5 elements changed their cluster assignment.
# 65
#         9 elements changed their cluster assignment.
# 66
#         9 elements changed their cluster assignment.
# 67
#         9 elements changed their cluster assignment.
# 68
#        10 elements changed their cluster assignment.
# 69
#         6 elements changed their cluster assignment.
# 70
#         3 elements changed their cluster assignment.
# 71
#         5 elements changed their cluster assignment.
# 72
#         2 elements changed their cluster assignment.
# 73
#         1 elements changed their cluster assignment.
# 74
#         1 elements changed their cluster assignment.
# 75
# seed=020000, heterogeneity=56351.77299
# 0
# 1
#     24101 elements changed their cluster assignment.
# 2
#     11625 elements changed their cluster assignment.
# 3
#      7070 elements changed their cluster assignment.
# 4
#      4137 elements changed their cluster assignment.
# 5
#      2673 elements changed their cluster assignment.
# 6
#      1538 elements changed their cluster assignment.
# 7
#      1040 elements changed their cluster assignment.
# 8
#       709 elements changed their cluster assignment.
# 9
#       483 elements changed their cluster assignment.
# 10
#       326 elements changed their cluster assignment.
# 11
#       243 elements changed their cluster assignment.
# 12
#       222 elements changed their cluster assignment.
# 13
#       196 elements changed their cluster assignment.
# 14
#       163 elements changed their cluster assignment.
# 15
#       121 elements changed their cluster assignment.
# 16
#       119 elements changed their cluster assignment.
# 17
#       100 elements changed their cluster assignment.
# 18
#        82 elements changed their cluster assignment.
# 19
#        67 elements changed their cluster assignment.
# 20
#        65 elements changed their cluster assignment.
# 21
#        57 elements changed their cluster assignment.
# 22
#        53 elements changed their cluster assignment.
# 23
#        48 elements changed their cluster assignment.
# 24
#        35 elements changed their cluster assignment.
# 25
#        41 elements changed their cluster assignment.
# 26
#        47 elements changed their cluster assignment.
# 27
#        41 elements changed their cluster assignment.
# 28
#        42 elements changed their cluster assignment.
# 29
#        66 elements changed their cluster assignment.
# 30
#        73 elements changed their cluster assignment.
# 31
#        80 elements changed their cluster assignment.
# 32
#       101 elements changed their cluster assignment.
# 33
#       176 elements changed their cluster assignment.
# 34
#       268 elements changed their cluster assignment.
# 35
#       302 elements changed their cluster assignment.
# 36
#       221 elements changed their cluster assignment.
# 37
#       159 elements changed their cluster assignment.
# 38
#       101 elements changed their cluster assignment.
# 39
#       101 elements changed their cluster assignment.
# 40
#       112 elements changed their cluster assignment.
# 41
#       120 elements changed their cluster assignment.
# 42
#       141 elements changed their cluster assignment.
# 43
#       161 elements changed their cluster assignment.
# 44
#       187 elements changed their cluster assignment.
# 45
#       231 elements changed their cluster assignment.
# 46
#       256 elements changed their cluster assignment.
# 47
#       260 elements changed their cluster assignment.
# 48
#       235 elements changed their cluster assignment.
# 49
#       226 elements changed their cluster assignment.
# 50
#       213 elements changed their cluster assignment.
# 51
#       177 elements changed their cluster assignment.
# 52
#       173 elements changed their cluster assignment.
# 53
#       148 elements changed their cluster assignment.
# 54
#       137 elements changed their cluster assignment.
# 55
#       145 elements changed their cluster assignment.
# 56
#       159 elements changed their cluster assignment.
# 57
#       168 elements changed their cluster assignment.
# 58
#       169 elements changed their cluster assignment.
# 59
#       204 elements changed their cluster assignment.
# 60
#       167 elements changed their cluster assignment.
# 61
#        83 elements changed their cluster assignment.
# 62
#        46 elements changed their cluster assignment.
# 63
#        30 elements changed their cluster assignment.
# 64
#        27 elements changed their cluster assignment.
# 65
#        22 elements changed their cluster assignment.
# 66
#        21 elements changed their cluster assignment.
# 67
#         6 elements changed their cluster assignment.
# 68
#         3 elements changed their cluster assignment.
# 69
#         1 elements changed their cluster assignment.
# 70
#         1 elements changed their cluster assignment.
# 71
# seed=040000, heterogeneity=56299.53728
# 0
# 1
#     26887 elements changed their cluster assignment.
# 2
#     10478 elements changed their cluster assignment.
# 3
#      5898 elements changed their cluster assignment.
# 4
#      3810 elements changed their cluster assignment.
# 5
#      2611 elements changed their cluster assignment.
# 6
#      1791 elements changed their cluster assignment.
# 7
#      1200 elements changed their cluster assignment.
# 8
#       914 elements changed their cluster assignment.
# 9
#       622 elements changed their cluster assignment.
# 10
#       415 elements changed their cluster assignment.
# 11
#       288 elements changed their cluster assignment.
# 12
#       209 elements changed their cluster assignment.
# 13
#       194 elements changed their cluster assignment.
# 14
#       191 elements changed their cluster assignment.
# 15
#       179 elements changed their cluster assignment.
# 16
#       170 elements changed their cluster assignment.
# 17
#       215 elements changed their cluster assignment.
# 18
#       259 elements changed their cluster assignment.
# 19
#       299 elements changed their cluster assignment.
# 20
#       353 elements changed their cluster assignment.
# 21
#       377 elements changed their cluster assignment.
# 22
#       408 elements changed their cluster assignment.
# 23
#       446 elements changed their cluster assignment.
# 24
#       394 elements changed their cluster assignment.
# 25
#       345 elements changed their cluster assignment.
# 26
#       268 elements changed their cluster assignment.
# 27
#       204 elements changed their cluster assignment.
# 28
#       168 elements changed their cluster assignment.
# 29
#       149 elements changed their cluster assignment.
# 30
#       128 elements changed their cluster assignment.
# 31
#       105 elements changed their cluster assignment.
# 32
#        76 elements changed their cluster assignment.
# 33
#        76 elements changed their cluster assignment.
# 34
#        71 elements changed their cluster assignment.
# 35
#        45 elements changed their cluster assignment.
# 36
#        51 elements changed their cluster assignment.
# 37
#        44 elements changed their cluster assignment.
# 38
#        46 elements changed their cluster assignment.
# 39
#        45 elements changed their cluster assignment.
# 40
#        49 elements changed their cluster assignment.
# 41
#        45 elements changed their cluster assignment.
# 42
#        57 elements changed their cluster assignment.
# 43
#        76 elements changed their cluster assignment.
# 44
#       102 elements changed their cluster assignment.
# 45
#       136 elements changed their cluster assignment.
# 46
#       140 elements changed their cluster assignment.
# 47
#       129 elements changed their cluster assignment.
# 48
#        98 elements changed their cluster assignment.
# 49
#        63 elements changed their cluster assignment.
# 50
#        41 elements changed their cluster assignment.
# 51
#        25 elements changed their cluster assignment.
# 52
#        16 elements changed their cluster assignment.
# 53
#         7 elements changed their cluster assignment.
# 54
#         3 elements changed their cluster assignment.
# 55
# seed=060000, heterogeneity=56324.49665
# 0
# 1
#     24724 elements changed their cluster assignment.
# 2
#     11643 elements changed their cluster assignment.
# 3
#      5906 elements changed their cluster assignment.
# 4
#      3451 elements changed their cluster assignment.
# 5
#      2575 elements changed their cluster assignment.
# 6
#      1938 elements changed their cluster assignment.
# 7
#      1561 elements changed their cluster assignment.
# 8
#      1279 elements changed their cluster assignment.
# 9
#      1025 elements changed their cluster assignment.
# 10
#       893 elements changed their cluster assignment.
# 11
#       817 elements changed their cluster assignment.
# 12
#       753 elements changed their cluster assignment.
# 13
#       658 elements changed their cluster assignment.
# 14
#       501 elements changed their cluster assignment.
# 15
#       366 elements changed their cluster assignment.
# 16
#       322 elements changed their cluster assignment.
# 17
#       288 elements changed their cluster assignment.
# 18
#       274 elements changed their cluster assignment.
# 19
#       278 elements changed their cluster assignment.
# 20
#       256 elements changed their cluster assignment.
# 21
#       242 elements changed their cluster assignment.
# 22
#       234 elements changed their cluster assignment.
# 23
#       147 elements changed their cluster assignment.
# 24
#        89 elements changed their cluster assignment.
# 25
#        65 elements changed their cluster assignment.
# 26
#        48 elements changed their cluster assignment.
# 27
#        44 elements changed their cluster assignment.
# 28
#        44 elements changed their cluster assignment.
# 29
#        45 elements changed their cluster assignment.
# 30
#        43 elements changed their cluster assignment.
# 31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-9cecbd7ec18c> in <module>()
#      21                                                                num_runs=len(seed_list),
#      22                                                                seed_list=seed_list,
# ---> 23                                                                verbose=True)
#      24     score = compute_heterogeneity(tf_idf, k, centroids[k], cluster_assignment[k])
#      25     heterogeneity_values.append(score)
#
# <ipython-input-57-6f57faaf8d2b> in kmeans_multiple_runs(data, k, maxiter, num_runs, seed_list, verbose)
#      24         # YOUR CODE HERE
#      25         centroids, cluster_assignment = kmeans(data, k, initial_centroids, maxiter=maxiter,
# ---> 26                                            record_heterogeneity=None, verbose=verbose)
#      27
#      28         # To save time, compute heterogeneity only once in the end
#
# <ipython-input-47-cc7eb0ff98c9> in kmeans(data, k, initial_centroids, maxiter, record_heterogeneity, verbose)
#      19         # 2. Compute a new centroid for each of the k clusters, averaging all data points assigned to that cluster.
#      20         # YOUR CODE HERE
# ---> 21         centroids = revise_centroids(data, k, cluster_assignment)
#      22
#      23         # Check for convergence: if none of the assignments changed, stop
#
# <ipython-input-43-c4c94613e164> in revise_centroids(data, k, cluster_assignment)
#       5         member_data_points = data[cluster_assignment==i]
#       6         # Compute the mean of the data points. Fill in the blank (RHS only)
# ----> 7         centroid = member_data_points.mean(axis=0)
#       8
#       9         # Convert numpy.matrix type to numpy.ndarray type
#
# /Users/gniemiec/anaconda/envs/gl-env/lib/python2.7/site-packages/scipy/sparse/base.pyc in mean(self, axis)
#     737         if axis == 0:
#     738             mean = self.astype(res_dtype).sum(0)
# --> 739             mean *= 1.0 / self.shape[0]
#     740             return mean
#     741         elif axis == 1:
#
# /Users/gniemiec/anaconda/envs/gl-env/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.pyc in __imul__(self, other)
#     350
#     351     def __imul__(self, other):
# --> 352         self[:] = self * other
#     353         return self
#     354
#
# /Users/gniemiec/anaconda/envs/gl-env/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.pyc in __mul__(self, other)
#     343             return N.dot(self, asmatrix(other))
#     344         if isscalar(other) or not hasattr(other, '__rmul__') :
# --> 345             return N.dot(self, other)
#     346         return NotImplemented
#     347
#
# /Users/gniemiec/anaconda/envs/gl-env/lib/python2.7/site-packages/numpy/matrixlib/defmatrix.pyc in __array_finalize__(self, obj)
#     290         return ret
#     291
# --> 292     def __array_finalize__(self, obj):
#     293         self._getitem = False
#     294         if (isinstance(obj, matrix) and obj._getitem): return
#
# KeyboardInterrupt:

# %% [markdown]
# To use the pre-computed NumPy arrays, first download kmeans-arrays.npz as mentioned in the reading for this assignment and load them with the following code.  Make sure the downloaded file is in the same directory as this notebook.

# %%
def plot_k_vs_heterogeneity(k_values, heterogeneity_values):
    plt.figure(figsize=(7,4))
    plt.plot(k_values, heterogeneity_values, linewidth=4)
    plt.xlabel('K')
    plt.ylabel('Heterogeneity')
    plt.title('K vs. Heterogeneity')
    plt.rcParams.update({'font.size': 16})
    plt.tight_layout()

filename = 'kmeans-arrays.npz'

heterogeneity_values = []
k_list = [2, 10, 25, 50, 100]

if os.path.exists(filename):
    arrays = np.load(filename)
    centroids = {}
    cluster_assignment = {}
    for k in k_list:
        print k
        sys.stdout.flush()
        '''To save memory space, do not load the arrays from the file right away. We use
           a technique known as lazy evaluation, where some expressions are not evaluated
           until later. Any expression appearing inside a lambda function doesn't get
           evaluated until the function is called.
           Lazy evaluation is extremely important in memory-constrained setting, such as
           an Amazon EC2 t2.micro instance.'''
        centroids[k] = lambda k=k: arrays['centroids_{0:d}'.format(k)]
        cluster_assignment[k] = lambda k=k: arrays['cluster_assignment_{0:d}'.format(k)]
        score = compute_heterogeneity(tf_idf, k, centroids[k](), cluster_assignment[k]())
        heterogeneity_values.append(score)
    
    plot_k_vs_heterogeneity(k_list, heterogeneity_values)

else:
    print('File not found. Skipping.')

# %% [markdown]
# In the above plot we show that heterogeneity goes down as we increase the number of clusters. Does this mean we should always favor a higher K? **Not at all!** As we will see in the following section, setting K too high may end up separating data points that are actually pretty alike. At the extreme, we can set individual data points to be their own clusters (K=N) and achieve zero heterogeneity, but separating each data point into its own cluster is hardly a desirable outcome. In the following section, we will learn how to detect a K set "too large".

# %% [markdown]
# ## Visualize clusters of documents

# %% [markdown]
# Let's start visualizing some clustering results to see if we think the clustering makes sense.  We can use such visualizations to help us assess whether we have set K too large or too small for a given application.  Following the theme of this course, we will judge whether the clustering makes sense in the context of document analysis.
#
# What are we looking for in a good clustering of documents?
# * Documents in the same cluster should be similar.
# * Documents from different clusters should be less similar.
#
# So a bad clustering exhibits either of two symptoms:
# * Documents in a cluster have mixed content.
# * Documents with similar content are divided up and put into different clusters.
#
# To help visualize the clustering, we do the following:
# * Fetch nearest neighbors of each centroid from the set of documents assigned to that cluster. We will consider these documents as being representative of the cluster.
# * Print titles and first sentences of those nearest neighbors.
# * Print top 5 words that have highest tf-idf weights in each centroid.

# %%
def visualize_document_clusters(wiki, tf_idf, centroids, cluster_assignment, k, map_index_to_word, display_content=True):
    '''wiki: original dataframe
       tf_idf: data matrix, sparse matrix format
       map_index_to_word: SFrame specifying the mapping betweeen words and column indices
       display_content: if True, display 8 nearest neighbors of each centroid'''
    
    print('==========================================================')

    # Visualize each cluster c
    for c in xrange(k):
        # Cluster heading
        print('Cluster {0:d}    '.format(c)),
        # Print top 5 words with largest TF-IDF weights in the cluster
        idx = centroids[c].argsort()[::-1]
        for i in xrange(5): # Print each word along with the TF-IDF weight
            print('{0:s}:{1:.3f}'.format(map_index_to_word['category'][idx[i]], centroids[c,idx[i]])),
        print('')
        
        if display_content:
            # Compute distances from the centroid to all data points in the cluster,
            # and compute nearest neighbors of the centroids within the cluster.
            distances = pairwise_distances(tf_idf, centroids[c].reshape(1, -1), metric='euclidean').flatten()
            distances[cluster_assignment!=c] = float('inf') # remove non-members from consideration
            nearest_neighbors = distances.argsort()
            # For 8 nearest neighbors, print the title as well as first 180 characters of text.
            # Wrap the text at 80-character mark.
            for i in xrange(8):
                text = ' '.join(wiki[nearest_neighbors[i]]['text'].split(None, 25)[0:25])
                print('\n* {0:50s} {1:.5f}\n  {2:s}\n  {3:s}'.format(wiki[nearest_neighbors[i]]['name'],
                    distances[nearest_neighbors[i]], text[:90], text[90:180] if len(text) > 90 else ''))
        print('==========================================================')

# %% [markdown]
# Let us first look at the 2 cluster case (K=2).

# %%
'''Notice the extra pairs of parentheses for centroids and cluster_assignment.
   The centroid and cluster_assignment are still inside the npz file,
   and we need to explicitly indicate when to load them into memory.'''
visualize_document_clusters(wiki, tf_idf, centroids[2](), cluster_assignment[2](), 2, map_index_to_word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-49018741f65b> in <module>()
#       2    The centroid and cluster_assignment are still inside the npz file,
#       3    and we need to explicitly indicate when to load them into memory.'''
# ----> 4 visualize_document_clusters(wiki, tf_idf, centroids[2](), cluster_assignment[2](), 2, map_index_to_word)
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# Both clusters have mixed content, although cluster 1 is much purer than cluster 0:
# * Cluster 0: artists, songwriters, professors, politicians, writers, etc.
# * Cluster 1: baseball players, hockey players, football (soccer) players, etc.
#
# Top words of cluster 1 are all related to sports, whereas top words of cluster 0 show no clear pattern.
#
# Roughly speaking, the entire dataset was divided into athletes and non-athletes. It would be better if we sub-divided non-athletes into more categories. So let us use more clusters. How about `K=10`?

# %%
k = 10
visualize_document_clusters(wiki, tf_idf, centroids[k](), cluster_assignment[k](), k, map_index_to_word)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-c6d0f030a32e> in <module>()
#       1 k = 10
# ----> 2 visualize_document_clusters(wiki, tf_idf, centroids[k](), cluster_assignment[k](), k, map_index_to_word)
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# Clusters 0 and 2 appear to be still mixed, but others are quite consistent in content.
# * Cluster 0: artists, poets, writers, environmentalists
# * Cluster 1: film directors
# * Cluster 2: female figures from various fields
# * Cluster 3: politicians
# * Cluster 4: track and field athletes
# * Cluster 5: composers, songwriters, singers, music producers
# * Cluster 6: soccer (football) players
# * Cluster 7: baseball players
# * Cluster 8: professors, researchers, scholars
# * Cluster 9: lawyers, judges, legal scholars
#
# Clusters are now more pure, but some are qualitatively "bigger" than others. For instance, the category of scholars is more general than the category of baseball players. Increasing the number of clusters may split larger clusters. Another way to look at the size of the clusters is to count the number of articles in each cluster.

# %%
cluster_assignment[10]
# Out:
# array([6, 0, 5, ..., 6, 6, 0])

# %%
np.bincount(cluster_assignment[10]())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-0c2a9c684d28> in <module>()
# ----> 1 np.bincount(cluster_assignment[10]())
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# **Quiz Question**. Which of the 10 clusters above contains the greatest number of articles?
#
# 1. Cluster 0: artists, poets, writers, environmentalists
# 2. Cluster 4: track and field athletes
# 3. Cluster 5: composers, songwriters, singers, music producers
# 4. Cluster 7: baseball players
# 5. Cluster 9: lawyers, judges, legal scholars

# %% [markdown]
# **Quiz Question**. Which of the 10 clusters contains the least number of articles?
#
# 1. Cluster 1: film directors
# 2. Cluster 3: politicians
# 3. Cluster 6: soccer (football) players
# 4. Cluster 7: baseball players
# 5. Cluster 9: lawyers, judges, legal scholars

# %% [markdown]
# There appears to be at least some connection between the topical consistency of a cluster and the number of its member data points.

# %% [markdown]
# Let us visualize the case for K=25. For the sake of brevity, we do not print the content of documents. It turns out that the top words with highest TF-IDF weights in each cluster are representative of the cluster.

# %%
visualize_document_clusters(wiki, tf_idf, centroids[25](), cluster_assignment[25](), 25,
                            map_index_to_word, display_content=False) # turn off text for brevity
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-c3dc900024c6> in <module>()
# ----> 1 visualize_document_clusters(wiki, tf_idf, centroids[25](), cluster_assignment[25](), 25,
#       2                             map_index_to_word, display_content=False) # turn off text for brevity
#
# TypeError: 'numpy.ndarray' object is not callable

# %% [markdown]
# Looking at the representative examples and top words, we classify each cluster as follows. Notice the bolded items, which indicate the appearance of a new theme.
# * Cluster 0: composers, songwriters, singers, music producers
# * Cluster 1: **poets**
# * Cluster 2: **rugby players**
# * Cluster 3: baseball players
# * Cluster 4: **government officials**
# * Cluster 5: football players
# * Cluster 6: **radio hosts**
# * Cluster 7: **actors, TV directors**
# * Cluster 8: professors, researchers, scholars
# * Cluster 9: lawyers, judges, legal scholars
# * Cluster 10: track and field athletes
# * Cluster 11: (mixed; no clear theme)
# * Cluster 12: **car racers**
# * Cluster 13: **priests, bishops, church leaders**
# * Cluster 14: painters, sculptors, artists
# * Cluster 15: **novelists**
# * Cluster 16: **American football players**
# * Cluster 17: **golfers**
# * Cluster 18: American politicians
# * Cluster 19: **basketball players**
# * Cluster 20: **generals of U.S. Air Force**
# * Cluster 21: politicians
# * Cluster 22: female figures of various fields
# * Cluster 23: film directors
# * Cluster 24: music directors, composers, conductors
#
# Indeed, increasing K achieved the desired effect of breaking up large clusters.  Depending on the application, this may or may not be preferable to the K=10 analysis.
#
# Let's take it to the extreme and set K=100. We have a suspicion that this value is too large. Let us look at the top words from each cluster:

# %%
k=100
visualize_document_clusters(wiki, tf_idf, centroids[k](), cluster_assignment[k](), k,
                            map_index_to_word, display_content=False)
# turn off text for brevity -- turn it on if you are curious ;)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-da5c4a127c13> in <module>()
#       1 k=100
# ----> 2 visualize_document_clusters(wiki, tf_idf, centroids[k](), cluster_assignment[k](), k,
#       3                             map_index_to_word, display_content=False)
#       4 # turn off text for brevity -- turn it on if you are curious ;)
#
# KeyError: 100

# %% [markdown]
# The class of rugby players has been broken into two clusters (11 and 72). The same goes for soccer (football) players (clusters 6, 21, 40, and 87), although some may like the benefit of having a separate category for Australian Football League. The class of baseball players has also been broken into two clusters (18 and 95).
#
# **A high value of K encourages pure clusters, but we cannot keep increasing K. For large enough K, related documents end up going to different clusters.**
#
# That said, the result for K=100 is not entirely bad. After all, it gives us separate clusters for such categories as Scotland, Brazil, LGBT, computer science and the Mormon Church. If we set K somewhere between 25 and 100, we should be able to avoid breaking up clusters while discovering new ones.
#
# Also, we should ask ourselves how much **granularity** we want in our clustering. If we wanted a rough sketch of Wikipedia, we don't want too detailed clusters. On the other hand, having many clusters can be valuable when we are zooming into a certain part of Wikipedia.
#
# **There is no golden rule for choosing K. It all depends on the particular application and domain we are in.**
#
# Another heuristic people use that does not rely on so much visualization, which can be hard in many applications (including here!) is as follows.  Track heterogeneity versus K and look for the "elbow" of the curve where the heterogeneity decrease rapidly before this value of K, but then only gradually for larger values of K.  This naturally trades off between trying to minimize heterogeneity, but reduce model complexity.  In the heterogeneity versus K plot made above, we did not yet really see a flattening out of the heterogeneity, which might indicate that indeed K=100 is "reasonable" and we only see real overfitting for larger values of K (which are even harder to visualize using the methods we attempted above.)

# %% [markdown]
# **Quiz Question**. Another sign of too large K is having lots of small clusters. Look at the distribution of cluster sizes (by number of member data points). How many of the 100 clusters have fewer than 236 articles, i.e. 0.4% of the dataset?
#
# Hint: Use `cluster_assignment[100]()`, with the extra pair of parentheses for delayed loading.

# %%
sum(np.bincount(cluster_assignment[100]()) < 236)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-6e5ca302efd1> in <module>()
# ----> 1 sum(np.bincount(cluster_assignment[100]()) < 236)
#
# KeyError: 100

# %%
np.bincount(cluster_assignment[100]())<236
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-37f0f18ef0ea> in <module>()
# ----> 1 np.bincount(cluster_assignment[100]())<236
#
# KeyError: 100

# %% [markdown]
# ### Takeaway
#
# Keep in mind though that tiny clusters aren't necessarily bad. A tiny cluster of documents that really look like each others is definitely preferable to a medium-sized cluster of documents with mixed content. However, having too few articles in a cluster may cause overfitting by reading too much into a limited pool of training data.
